# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import networkx as nx 
import matplotlib.pyplot as plt
import re

# %%
CATALOG_URL = 'https://app.testudo.umd.edu/soc/202508/'
COURSE_PATTERN = re.compile(r"\b[A-Z]{4}\d{3}\b")

# %%
def get_prereq(department):
    
    url = f"{CATALOG_URL}{department}"
    
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    
    courses = {}
    
    
    for course_div in soup.find_all("div", class_="course"):
        course_id = course_div.get("id")
        
        if not course_id: 
            continue
        
        # TODO: remove when done
        print(course_id)
        
        prereq_text = ""
        
        prereq_div = course_div.find("div", class_="approved-course-texts-container")
        if prereq_div: 
            prereq_section = prereq_div.find("strong", string="Prerequisite:")
            if prereq_section: 
                prereq_text = prereq_section.next_sibling.strip() if prereq_section.next_sibling else ""
                
        prerequisites = COURSE_PATTERN.findall(prereq_text)
        courses[course_id] = prerequisites
        
    
    return courses

# %%
# Example: Get prerequisites for STEM Departments UMD offers
departments = [
    "AOSC", "ANSC", "ASTR", "BCHM", "BIOE", "BIOL", "BIPH", "CBMG", "CHBE", "CHEM",
    "CMSC", "ENCE", "ENAE", "ENEE", "ENFP", "ENMA", "ENME", "ENSP", "ENST", "ENTM",
    "GEOG", "GEOL", "MATH", "NEUR", "PHYS", "PLSC", "STAT", "INST", "DATA"
]
umd_courses = {}

for dept in departments:
    umd_courses.update(get_prereq(dept))
# Out:
# AOSC123
# AOSC200
# AOSC201
# AOSC375
# AOSC400
# AOSC420
# AOSC431
# AOSC440
# AOSC470
# AOSC493
# AOSC494
# AOSC499
# AOSC600
# AOSC610
# AOSC620
# AOSC642
# AOSC652
# AOSC670
# AOSC680
# AOSC798
# AOSC898
# AOSC899
# ANSC101
# ANSC103
# ANSC105
# ANSC201
# ANSC210
# ANSC232
# ANSC242
# ANSC246
# ANSC252
# ANSC255
# ANSC260
# ANSC270
# ANSC314
# ANSC359
# ANSC371
# ANSC388
# ANSC389
# ANSC399
# ANSC436
# ANSC437
# ANSC446
# ANSC447
# ANSC450
# ANSC454
# ANSC455
# ANSC460
# ANSC624
# ANSC625
# ANSC660
# ANSC688I
# ANSC688O
# ANSC699
# ANSC799
# ANSC898
# ANSC899
# ASTR100
# ASTR101
# ASTR120
# ASTR230
# ASTR288
# ASTR288B
# ASTR288I
# ASTR310
# ASTR330
# ASTR340
# ASTR350
# ASTR380
# ASTR399
# ASTR421
# ASTR422
# ASTR498
# ASTR601
# ASTR610
# ASTR622
# ASTR688B
# ASTR695
# ASTR699
# ASTR799
# ASTR898
# ASTR899
# BCHM461
# BCHM462
# BCHM463
# BCHM464
# BCHM465
# BCHM477
# BCHM661
# BCHM662
# BCHM671
# BCHM698
# BCHM699
# BCHM799
# BCHM889A
# BCHM889C
# BCHM889D
# BCHM889F
# BCHM889J
# BCHM889M
# BCHM889P
# BCHM898
# BCHM899
# BIOE120
# BIOE121
# BIOE221
# BIOE232
# BIOE241
# BIOE246
# BIOE331
# BIOE340
# BIOE371
# BIOE372
# BIOE389M
# BIOE399
# BIOE399H
# BIOE411
# BIOE413
# BIOE420
# BIOE437
# BIOE442
# BIOE453
# BIOE457
# BIOE461
# BIOE462
# BIOE485
# BIOE488B
# BIOE489H
# BIOE602
# BIOE605
# BIOE608
# BIOE610
# BIOE689
# BIOE689F
# BIOE689J
# BIOE799
# BIOE898
# BIOE899
# BIOL608K
# BIOL609
# BIOL667
# BIOL704
# BIOL708B
# BIOL709C
# BIOL709W
# BIOL799
# BIOL898
# BIOL899
# BIPH698L
# BIPH699
# BIPH704
# BIPH799
# BIPH898
# BIPH899
# CBMG688C
# CBMG688D
# CBMG688J
# CBMG688K
# CBMG688W
# CBMG699
# CBMG699D
# CBMG699K
# CBMG699X
# CBMG799
# CBMG898
# CBMG899
# CHBE100
# CHBE250
# CHBE301
# CHBE333
# CHBE369
# CHBE410
# CHBE422
# CHBE437
# CHBE440
# CHBE442
# CHBE444
# CHBE452
# CHBE468
# CHBE469
# CHBE472
# CHBE474
# CHBE490
# CHBE493
# CHBE494
# CHBE608
# CHBE609
# CHBE610
# CHBE620
# CHBE648
# CHBE652
# CHBE672
# CHBE673
# CHBE690
# CHBE799
# CHBE898
# CHBE899
# CHEM131
# CHEM132
# CHEM132C
# CHEM132S
# CHEM134
# CHEM135
# CHEM136
# CHEM146
# CHEM177
# CHEM231
# CHEM232
# CHEM241
# CHEM242
# CHEM247
# CHEM271
# CHEM272
# CHEM277
# CHEM398
# CHEM399A
# CHEM399B
# CHEM399C
# CHEM399X
# CHEM403
# CHEM425
# CHEM441
# CHEM460
# CHEM480
# CHEM481
# CHEM482
# CHEM483
# CHEM484
# CHEM601
# CHEM608K
# CHEM611
# CHEM625
# CHEM640
# CHEM641
# CHEM684
# CHEM690
# CHEM699
# CHEM799
# CHEM889A
# CHEM889C
# CHEM889D
# CHEM889E
# CHEM889F
# CHEM889M
# CHEM898
# CHEM899
# CMSC100
# CMSC106
# CMSC122
# CMSC125
# CMSC131
# CMSC132
# CMSC133
# CMSC216
# CMSC250
# CMSC298A
# CMSC320
# CMSC330
# CMSC335
# CMSC351
# CMSC396H
# CMSC411
# CMSC412
# CMSC414
# CMSC416
# CMSC417
# CMSC420
# CMSC421
# CMSC422
# CMSC423
# CMSC424
# CMSC425
# CMSC426
# CMSC430
# CMSC433
# CMSC434
# CMSC435
# CMSC436
# CMSC451
# CMSC454
# CMSC456
# CMSC460
# CMSC466
# CMSC470
# CMSC471
# CMSC473
# CMSC474
# CMSC475
# CMSC498A
# CMSC498B
# CMSC498J
# CMSC498K
# CMSC498Z
# CMSC499A
# CMSC616
# CMSC631
# CMSC634
# CMSC657
# CMSC660
# CMSC673
# CMSC702
# CMSC723
# CMSC740
# CMSC798
# CMSC799
# CMSC801
# CMSC818I
# CMSC818J
# CMSC818T
# CMSC818V
# CMSC828J
# CMSC828V
# CMSC838B
# CMSC838L
# CMSC839A
# CMSC839C
# CMSC839E
# CMSC848B
# CMSC848I
# CMSC848K
# CMSC848P
# CMSC858J
# CMSC858U
# CMSC898
# CMSC899
# ENCE100
# ENCE200
# ENCE201
# ENCE205
# ENCE215
# ENCE300
# ENCE302
# ENCE305
# ENCE310
# ENCE320
# ENCE325
# ENCE340
# ENCE353
# ENCE360
# ENCE370
# ENCE411
# ENCE422
# ENCE423
# ENCE424
# ENCE426
# ENCE432
# ENCE433
# ENCE441
# ENCE444
# ENCE454
# ENCE465
# ENCE470
# ENCE489
# ENCE489L
# ENCE602
# ENCE607
# ENCE613
# ENCE614
# ENCE620
# ENCE622
# ENCE627
# ENCE633
# ENCE640
# ENCE650
# ENCE651
# ENCE652
# ENCE662
# ENCE664
# ENCE666
# ENCE670
# ENCE672
# ENCE688B
# ENCE688I
# ENCE688T
# ENCE689
# ENCE799
# ENCE898
# ENCE899
# ENAE100
# ENAE202
# ENAE283
# ENAE283H
# ENAE301
# ENAE311
# ENAE311H
# ENAE362
# ENAE380
# ENAE398H
# ENAE403
# ENAE414
# ENAE423
# ENAE423H
# ENAE441
# ENAE455
# ENAE457
# ENAE457H
# ENAE472
# ENAE481
# ENAE483
# ENAE488G
# ENAE499
# ENAE601
# ENAE603
# ENAE631
# ENAE636
# ENAE641
# ENAE651
# ENAE655
# ENAE662
# ENAE673
# ENAE681
# ENAE682
# ENAE684
# ENAE788D
# ENAE788G
# ENAE788L
# ENAE788X
# ENAE799
# ENAE898
# ENAE899
# ENEE101
# ENEE140
# ENEE150
# ENEE200
# ENEE205
# ENEE222
# ENEE244
# ENEE245
# ENEE290
# ENEE304
# ENEE305
# ENEE322
# ENEE323
# ENEE324
# ENEE350
# ENEE382
# ENEE408A
# ENEE408C
# ENEE408I
# ENEE408V
# ENEE411
# ENEE416
# ENEE420
# ENEE425
# ENEE428
# ENEE429Z
# ENEE436
# ENEE439Q
# ENEE440
# ENEE445
# ENEE446
# ENEE457
# ENEE459A
# ENEE459B
# ENEE460
# ENEE467
# ENEE474
# ENEE476
# ENEE484
# ENEE486
# ENEE488
# ENEE489R
# ENEE489W
# ENEE499
# ENEE499H
# ENEE600
# ENEE611
# ENEE620
# ENEE630
# ENEE634
# ENEE641
# ENEE646
# ENEE660
# ENEE662
# ENEE680
# ENEE690
# ENEE698Q
# ENEE699
# ENEE719D
# ENEE739F
# ENEE739Z
# ENEE759C
# ENEE765
# ENEE789D
# ENEE789W
# ENEE799
# ENEE898
# ENEE899
# ENFP101
# ENFP250
# ENFP300
# ENFP405
# ENFP410
# ENFP415
# ENFP425
# ENFP429
# ENFP440
# ENFP467
# ENFP489
# ENFP601
# ENFP610
# ENFP619
# ENFP621
# ENFP626
# ENFP627
# ENFP629
# ENFP630
# ENFP649
# ENFP651
# ENFP653
# ENFP664
# ENFP667
# ENFP799
# ENMA180
# ENMA300
# ENMA312
# ENMA362
# ENMA414
# ENMA422
# ENMA437
# ENMA441
# ENMA460
# ENMA464
# ENMA466
# ENMA471
# ENMA473
# ENMA486
# ENMA487
# ENMA499
# ENMA613
# ENMA614
# ENMA637
# ENMA641
# ENMA650
# ENMA660
# ENMA664
# ENMA688
# ENMA698
# ENMA797
# ENMA799
# ENMA898
# ENMA899
# ENME202
# ENME208
# ENME272
# ENME299Z
# ENME331
# ENME332
# ENME350
# ENME351
# ENME361
# ENME371
# ENME382
# ENME392
# ENME400
# ENME401
# ENME408
# ENME416
# ENME422
# ENME423
# ENME425
# ENME426
# ENME430
# ENME432
# ENME434
# ENME440
# ENME441
# ENME444
# ENME454
# ENME462
# ENME467
# ENME470
# ENME472
# ENME473
# ENME480
# ENME488
# ENME489
# ENME489F
# ENME489O
# ENME489U
# ENME489V
# ENME605
# ENME610
# ENME631
# ENME640
# ENME645
# ENME662
# ENME690
# ENME691
# ENME692
# ENME694
# ENME722
# ENME737
# ENME743
# ENME744
# ENME750
# ENME753
# ENME799
# ENME808
# ENME808Q
# ENME898
# ENME899
# ENSP101
# ENSP305
# ENSP330
# ENSP340
# ENSP386
# ENSP399
# ENSP399N
# ENSP399R
# ENSP400
# ENSP499
# ENST101
# ENST115
# ENST200
# ENST233
# ENST281
# ENST282
# ENST301
# ENST302
# ENST303
# ENST333
# ENST360
# ENST388
# ENST389
# ENST403
# ENST411
# ENST414
# ENST415
# ENST417
# ENST432
# ENST441
# ENST450
# ENST456
# ENST460
# ENST472
# ENST485
# ENST486
# ENST489
# ENST499
# ENST499A
# ENST499E
# ENST499L
# ENST499X
# ENST499Y
# ENST602
# ENST603
# ENST606
# ENST611
# ENST650
# ENST689
# ENST689M
# ENST689X
# ENST689Y
# ENST689Z
# ENST761
# ENST798
# ENST799
# ENST898
# ENST899
# ENTM699K
# ENTM701
# ENTM788C
# ENTM798T
# ENTM799
# ENTM898
# ENTM899
# GEOG140
# GEOG156
# GEOG170
# GEOG172
# GEOG201
# GEOG202
# GEOG211
# GEOG272
# GEOG276
# GEOG330
# GEOG371
# GEOG373
# GEOG384
# GEOG385
# GEOG398
# GEOG416
# GEOG417
# GEOG418
# GEOG440
# GEOG475
# GEOG498
# GEOG498G
# GEOG498N
# GEOG601
# GEOG608
# GEOG617
# GEOG652
# GEOG653
# GEOG654
# GEOG661
# GEOG662
# GEOG686
# GEOG688M
# GEOG788
# GEOG788F
# GEOG788L
# GEOG788P
# GEOG788Z
# GEOG789
# GEOG790
# GEOG797
# GEOG798
# GEOG799
# GEOG898
# GEOG899
# GEOL100
# GEOL104
# GEOL110
# GEOL120
# GEOL123
# GEOL200
# GEOL212
# GEOL341
# GEOL342
# GEOL375
# GEOL386
# GEOL393
# GEOL394
# GEOL413
# GEOL423
# GEOL436
# GEOL444
# GEOL446
# GEOL451
# GEOL452
# GEOL453
# GEOL460
# GEOL488
# GEOL499
# GEOL613
# GEOL636
# GEOL650
# GEOL652
# GEOL670
# GEOL688
# GEOL789C
# GEOL789F
# GEOL798
# GEOL799
# GEOL898
# GEOL899
# MATH003
# MATH007
# MATH013
# MATH015
# MATH107
# MATH113
# MATH115
# MATH120
# MATH121
# MATH135
# MATH136
# MATH140
# MATH140H
# MATH141
# MATH141H
# MATH206
# MATH212
# MATH213
# MATH214
# MATH240
# MATH241
# MATH241H
# MATH243
# MATH246
# MATH246H
# MATH274
# MATH299B
# MATH310
# MATH312
# MATH315
# MATH340
# MATH386
# MATH401
# MATH402
# MATH403
# MATH405
# MATH406
# MATH407
# MATH410
# MATH411
# MATH416
# MATH423
# MATH424
# MATH430
# MATH431
# MATH432
# MATH436
# MATH445
# MATH456
# MATH461
# MATH462
# MATH463
# MATH464
# MATH475
# MATH489
# MATH498A
# MATH600
# MATH602
# MATH606
# MATH630
# MATH634
# MATH642
# MATH669
# MATH673
# MATH689
# MATH695
# MATH712
# MATH730
# MATH742
# MATH799
# MATH808A
# MATH808J
# MATH808L
# MATH818A
# MATH818T
# MATH838D
# MATH848A
# MATH848N
# MATH848T
# MATH858A
# MATH858I
# MATH868A
# MATH898
# MATH899
# NEUR200
# NEUR305
# NEUR306
# NEUR329
# NEUR379
# NEUR379H
# NEUR398H
# NEUR405
# NEUR479
# NEUR479H
# PHYS102
# PHYS103
# PHYS105
# PHYS115
# PHYS121
# PHYS122
# PHYS131
# PHYS132
# PHYS161
# PHYS170
# PHYS171
# PHYS171H
# PHYS172
# PHYS174
# PHYS235
# PHYS260
# PHYS260H
# PHYS261
# PHYS265
# PHYS270
# PHYS271
# PHYS272
# PHYS272H
# PHYS273
# PHYS273H
# PHYS275
# PHYS276
# PHYS299
# PHYS299E
# PHYS299W
# PHYS313
# PHYS331
# PHYS371
# PHYS375
# PHYS386
# PHYS389
# PHYS398
# PHYS399
# PHYS401
# PHYS402
# PHYS404
# PHYS405
# PHYS407
# PHYS410
# PHYS413
# PHYS431
# PHYS467
# PHYS485
# PHYS488P
# PHYS499A
# PHYS499B
# PHYS499V
# PHYS610
# PHYS612
# PHYS624
# PHYS625
# PHYS675
# PHYS685
# PHYS688P
# PHYS709
# PHYS715
# PHYS728J
# PHYS738
# PHYS739
# PHYS749
# PHYS758E
# PHYS759
# PHYS761
# PHYS769
# PHYS778
# PHYS798
# PHYS798B
# PHYS798L
# PHYS798Q
# PHYS799
# PHYS838C
# PHYS839A
# PHYS859C
# PHYS898
# PHYS899
# PLSC115
# PLSC201
# PLSC203
# PLSC205
# PLSC206
# PLSC253
# PLSC389
# PLSC399
# PLSC404
# PLSC420
# PLSC433
# PLSC489E
# PLSC489R
# PLSC608
# PLSC608T
# PLSC799
# PLSC898
# PLSC899
# STAT100
# STAT110
# STAT386
# STAT400
# STAT401
# STAT410
# STAT420
# STAT426
# STAT430
# STAT440
# STAT464
# STAT470
# STAT498A
# STAT600
# STAT689
# STAT700
# STAT702
# STAT705
# STAT740
# STAT799
# STAT808A
# STAT818A
# STAT818E
# STAT818T
# STAT898
# STAT899
# INST101
# INST104
# INST123
# INST126
# INST151
# INST152
# INST153
# INST154
# INST155
# INST156
# INST201
# INST204
# INST204S
# INST210
# INST227
# INST228
# INST301
# INST309
# INST311
# INST314
# INST320
# INST326
# INST327
# INST335
# INST341
# INST346
# INST347
# INST352
# INST354
# INST362
# INST363
# INST364
# INST366
# INST367
# INST377
# INST380
# INST381
# INST388E
# INST388F
# INST402
# INST405
# INST406
# INST407
# INST408I
# INST408R
# INST408V
# INST408Z
# INST410
# INST414
# INST441
# INST442
# INST447
# INST451
# INST453
# INST454
# INST455
# INST461
# INST462
# INST464
# INST466
# INST490
# INST600
# INST604
# INST607
# INST608Q
# INST610
# INST611
# INST613
# INST615
# INST620
# INST627
# INST630
# INST631
# INST639N
# INST643
# INST650
# INST651
# INST653
# INST661
# INST680
# INST704
# INST705
# INST709
# INST710
# INST711
# INST728D
# INST728F
# INST731
# INST735
# INST737
# INST752
# INST753
# INST754
# INST760
# INST764
# INST771
# INST775
# INST782
# INST784
# INST787
# INST799
# INST800
# INST801
# INST818
# INST878D
# INST898
# INST899
# DATA110
# DATA120
# DATA200
# DATA250
# DATA350
# DATA400
# DATA601
# DATA602
# DATA603

# %%
for key, value in umd_courses.items(): 
    print(f'Course: {key}, Prereq: {value} ')
# Out:
# Course: AOSC123, Prereq: []
# Course: AOSC200, Prereq: ['MATH107', 'MATH110', 'MATH115']
# Course: AOSC201, Prereq: []
# Course: AOSC375, Prereq: ['MATH120']
# Course: AOSC400, Prereq: ['PHYS171', 'PHYS161', 'MATH141']
# Course: AOSC420, Prereq: ['MATH141', 'PHYS141']
# Course: AOSC431, Prereq: ['PHYS171', 'PHYS161', 'MATH141']
# Course: AOSC440, Prereq: ['PHYS171', 'PHYS161', 'AOSC401', 'GEOG301']
# Course: AOSC470, Prereq: ['AOSC431', 'AOSC432']
# Course: AOSC493, Prereq: []
# Course: AOSC494, Prereq: ['AOSC431', 'AOSC432']
# Course: AOSC499, Prereq: []
# Course: AOSC600, Prereq: ['AOSC610']
# Course: AOSC610, Prereq: ['MATH462']
# Course: AOSC620, Prereq: ['MATH461']
# Course: AOSC642, Prereq: ['PHYS171', 'PHYS161', 'AOSC401', 'GEOG301']
# Course: AOSC652, Prereq: ['PHYS141', 'MATH241']
# Course: AOSC670, Prereq: []
# Course: AOSC680, Prereq: []
# Course: AOSC798, Prereq: []
# Course: AOSC898, Prereq: []
# Course: AOSC899, Prereq: []
# Course: ANSC101, Prereq: []
# Course: ANSC103, Prereq: ['ANSC101']
# Course: ANSC105, Prereq: []
# Course: ANSC201, Prereq: ['ANSC101', 'ANSC103', 'BSCI170', 'BSCI171']
# Course: ANSC210, Prereq: ['ANSC204', 'ANSC205', 'ANSC201']
# Course: ANSC232, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC242, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC246, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC252, Prereq: ['BSCI105', 'BSCI170', 'BSCI171']
# Course: ANSC255, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC260, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC270, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC314, Prereq: ['ANSC101', 'ANSC103', 'CHEM231', 'PLSC275', 'AGST275']
# Course: ANSC359, Prereq: []
# Course: ANSC371, Prereq: []
# Course: ANSC388, Prereq: []
# Course: ANSC389, Prereq: []
# Course: ANSC399, Prereq: []
# Course: ANSC436, Prereq: []
# Course: ANSC437, Prereq: ['ANSC327']
# Course: ANSC446, Prereq: ['ANSC212', 'BSCI440']
# Course: ANSC447, Prereq: ['ANSC446']
# Course: ANSC450, Prereq: ['ANSC101', 'MATH120', 'MATH136', 'MATH140', 'BIOM301']
# Course: ANSC454, Prereq: ['CHEM131', 'ANSC101', 'BSCI170']
# Course: ANSC455, Prereq: ['ANSC101', 'ANSC103', 'BSCI106', 'BSCI160', 'BSCI161']
# Course: ANSC460, Prereq: ['ANSC212', 'BSCI201', 'BSCI440']
# Course: ANSC624, Prereq: []
# Course: ANSC625, Prereq: []
# Course: ANSC660, Prereq: []
# Course: ANSC688I, Prereq: []
# Course: ANSC688O, Prereq: []
# Course: ANSC699, Prereq: []
# Course: ANSC799, Prereq: []
# Course: ANSC898, Prereq: []
# Course: ANSC899, Prereq: []
# Course: ASTR100, Prereq: []
# Course: ASTR101, Prereq: []
# Course: ASTR120, Prereq: ['MATH140']
# Course: ASTR230, Prereq: ['MATH115', 'MATH113']
# Course: ASTR288, Prereq: []
# Course: ASTR288B, Prereq: []
# Course: ASTR288I, Prereq: []
# Course: ASTR310, Prereq: ['ASTR121', 'PHYS171', 'PHYS161']
# Course: ASTR330, Prereq: ['ASTR100', 'ASTR101']
# Course: ASTR340, Prereq: ['ASTR100', 'ASTR101']
# Course: ASTR350, Prereq: ['ASTR100', 'ASTR101']
# Course: ASTR380, Prereq: []
# Course: ASTR399, Prereq: []
# Course: ASTR421, Prereq: ['ASTR121', 'PHYS271', 'PHYS270', 'PHYS273']
# Course: ASTR422, Prereq: ['ASTR320']
# Course: ASTR498, Prereq: []
# Course: ASTR601, Prereq: []
# Course: ASTR610, Prereq: []
# Course: ASTR622, Prereq: []
# Course: ASTR688B, Prereq: []
# Course: ASTR695, Prereq: []
# Course: ASTR699, Prereq: []
# Course: ASTR799, Prereq: []
# Course: ASTR898, Prereq: []
# Course: ASTR899, Prereq: []
# Course: BCHM461, Prereq: ['CHEM271', 'CHEM272', 'CHEM276', 'CHEM277']
# Course: BCHM462, Prereq: ['BCHM461']
# Course: BCHM463, Prereq: ['CHEM271', 'CHEM272', 'CHEM276', 'CHEM277']
# Course: BCHM464, Prereq: ['BCHM461', 'BCHM463']
# Course: BCHM465, Prereq: ['BCHM461', 'BCHM463']
# Course: BCHM477, Prereq: ['CHEM271', 'CHEM276', 'CHEM277', 'CHEM272']
# Course: BCHM661, Prereq: ['BSCI410', 'BCHM465']
# Course: BCHM662, Prereq: ['BCHM661']
# Course: BCHM671, Prereq: ['BCHM461']
# Course: BCHM698, Prereq: []
# Course: BCHM699, Prereq: []
# Course: BCHM799, Prereq: []
# Course: BCHM889A, Prereq: []
# Course: BCHM889C, Prereq: []
# Course: BCHM889D, Prereq: []
# Course: BCHM889F, Prereq: []
# Course: BCHM889J, Prereq: []
# Course: BCHM889M, Prereq: []
# Course: BCHM889P, Prereq: []
# Course: BCHM898, Prereq: []
# Course: BCHM899, Prereq: []
# Course: BIOE120, Prereq: ['MATH140']
# Course: BIOE121, Prereq: ['BIOE120']
# Course: BIOE221, Prereq: ['BIOE120', 'BIOE121']
# Course: BIOE232, Prereq: ['PHYS261', 'PHYS260']
# Course: BIOE241, Prereq: []
# Course: BIOE246, Prereq: ['MATH243']
# Course: BIOE331, Prereq: ['MATH246', 'BIOE120', 'BIOE121', 'BIOE241', 'BIOE371', 'BIOE232']
# Course: BIOE340, Prereq: ['BSCI330', 'BIOE331']
# Course: BIOE371, Prereq: ['BIOE241', 'MATH246']
# Course: BIOE372, Prereq: ['BIOE120', 'BIOE121', 'BIOE241']
# Course: BIOE389M, Prereq: []
# Course: BIOE399, Prereq: []
# Course: BIOE399H, Prereq: []
# Course: BIOE411, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246', 'MATH241']
# Course: BIOE413, Prereq: ['BIOE241', 'BIOE120', 'BIOE121', 'MATH246', 'BIOE340']
# Course: BIOE420, Prereq: ['MATH246', 'BIOE120', 'BIOE121', 'BIOE241']
# Course: BIOE437, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246']
# Course: BIOE442, Prereq: ['BIOE241', 'BIOE120', 'BIOE121', 'MATH241']
# Course: BIOE453, Prereq: ['CHEM231', 'MATH246', 'CHEM232', 'BIOE120', 'BIOE121', 'BIOE241']
# Course: BIOE457, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'PHYS261', 'MATH246', 'PHYS260']
# Course: BIOE461, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246']
# Course: BIOE462, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246', 'BSCI330', 'BIOE340']
# Course: BIOE485, Prereq: ['BIOE457']
# Course: BIOE488B, Prereq: []
# Course: BIOE489H, Prereq: []
# Course: BIOE602, Prereq: []
# Course: BIOE605, Prereq: []
# Course: BIOE608, Prereq: []
# Course: BIOE610, Prereq: []
# Course: BIOE689, Prereq: []
# Course: BIOE689F, Prereq: []
# Course: BIOE689J, Prereq: []
# Course: BIOE799, Prereq: []
# Course: BIOE898, Prereq: []
# Course: BIOE899, Prereq: []
# Course: BIOL608K, Prereq: []
# Course: BIOL609, Prereq: []
# Course: BIOL667, Prereq: []
# Course: BIOL704, Prereq: []
# Course: BIOL708B, Prereq: []
# Course: BIOL709C, Prereq: []
# Course: BIOL709W, Prereq: []
# Course: BIOL799, Prereq: []
# Course: BIOL898, Prereq: []
# Course: BIOL899, Prereq: []
# Course: BIPH698L, Prereq: []
# Course: BIPH699, Prereq: []
# Course: BIPH704, Prereq: []
# Course: BIPH799, Prereq: []
# Course: BIPH898, Prereq: []
# Course: BIPH899, Prereq: []
# Course: CBMG688C, Prereq: []
# Course: CBMG688D, Prereq: []
# Course: CBMG688J, Prereq: []
# Course: CBMG688K, Prereq: []
# Course: CBMG688W, Prereq: []
# Course: CBMG699, Prereq: []
# Course: CBMG699D, Prereq: []
# Course: CBMG699K, Prereq: []
# Course: CBMG699X, Prereq: []
# Course: CBMG799, Prereq: []
# Course: CBMG898, Prereq: []
# Course: CBMG899, Prereq: []
# Course: CHBE100, Prereq: []
# Course: CHBE250, Prereq: ['CHBE101', 'MATH241']
# Course: CHBE301, Prereq: ['CHBE101', 'CHBE250', 'MATH241']
# Course: CHBE333, Prereq: []
# Course: CHBE369, Prereq: []
# Course: CHBE410, Prereq: ['CHBE250', 'MATH241', 'MATH246']
# Course: CHBE422, Prereq: ['CHBE101', 'CHBE250', 'MATH241', 'MATH246']
# Course: CHBE437, Prereq: ['CHBE424', 'CHBE426', 'CHBE440']
# Course: CHBE440, Prereq: ['CHBE301', 'MATH241', 'MATH246']
# Course: CHBE442, Prereq: ['CHBE424', 'CHBE426']
# Course: CHBE444, Prereq: ['CHBE424', 'CHBE426', 'CHBE440']
# Course: CHBE452, Prereq: []
# Course: CHBE468, Prereq: []
# Course: CHBE469, Prereq: []
# Course: CHBE472, Prereq: []
# Course: CHBE474, Prereq: ['BIOE120']
# Course: CHBE490, Prereq: []
# Course: CHBE493, Prereq: ['CHBE424', 'CHBE440']
# Course: CHBE494, Prereq: ['CHBE424', 'CHBE426', 'CHBE440']
# Course: CHBE608, Prereq: []
# Course: CHBE609, Prereq: []
# Course: CHBE610, Prereq: ['CHBE301', 'CHBE302']
# Course: CHBE620, Prereq: ['MATH246', 'CHBE250']
# Course: CHBE648, Prereq: []
# Course: CHBE652, Prereq: []
# Course: CHBE672, Prereq: []
# Course: CHBE673, Prereq: []
# Course: CHBE690, Prereq: ['ENCH640']
# Course: CHBE799, Prereq: []
# Course: CHBE898, Prereq: []
# Course: CHBE899, Prereq: []
# Course: CHEM131, Prereq: ['MATH120']
# Course: CHEM132, Prereq: ['MATH120']
# Course: CHEM132C, Prereq: ['MATH120']
# Course: CHEM132S, Prereq: ['MATH120']
# Course: CHEM134, Prereq: ['CHEM131', 'CHEM146']
# Course: CHEM135, Prereq: ['MATH120']
# Course: CHEM136, Prereq: ['CHEM135', 'MATH120']
# Course: CHEM146, Prereq: ['MATH140']
# Course: CHEM177, Prereq: ['MATH120']
# Course: CHEM231, Prereq: ['CHEM131', 'CHEM135', 'CHEM146', 'CHEM132', 'CHEM136', 'CHEM147', 'CHEM177']
# Course: CHEM232, Prereq: ['CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM146', 'CHEM147']
# Course: CHEM241, Prereq: ['CHEM231', 'CHEM232', 'CHEM237']
# Course: CHEM242, Prereq: ['CHEM231', 'CHEM232', 'CHEM237']
# Course: CHEM247, Prereq: ['CHEM237']
# Course: CHEM271, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM272, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM277, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM398, Prereq: []
# Course: CHEM399A, Prereq: []
# Course: CHEM399B, Prereq: []
# Course: CHEM399C, Prereq: []
# Course: CHEM399X, Prereq: []
# Course: CHEM403, Prereq: []
# Course: CHEM425, Prereq: ['CHEM272', 'CHEM271', 'CHEM276', 'CHEM277']
# Course: CHEM441, Prereq: ['CHEM480', 'CHEM481', 'CHEM241', 'CHEM247']
# Course: CHEM460, Prereq: ['CHEM243', 'CHEM247', 'CHEM241', 'CHEM242']
# Course: CHEM480, Prereq: ['CHEM276', 'CHEM271', 'CHEM277', 'CHEM272', 'MATH140', 'MATH136', 'PHYS260', 'PHYS261', 'PHYS132']
# Course: CHEM481, Prereq: ['CHEM135', 'CHEM271', 'CHEM272', 'CHEM276', 'CHEM277', 'MATH141', 'PHYS260', 'PHYS261', 'PHYS141']
# Course: CHEM482, Prereq: ['CHEM135', 'CHEM271', 'CHEM272', 'CHEM276', 'CHEM277', 'MATH141', 'PHYS260', 'PHYS261', 'PHYS141']
# Course: CHEM483, Prereq: ['CHEM481']
# Course: CHEM484, Prereq: ['CHEM482']
# Course: CHEM601, Prereq: []
# Course: CHEM608K, Prereq: []
# Course: CHEM611, Prereq: []
# Course: CHEM625, Prereq: ['CHEM482']
# Course: CHEM640, Prereq: []
# Course: CHEM641, Prereq: []
# Course: CHEM684, Prereq: ['CHEM482']
# Course: CHEM690, Prereq: []
# Course: CHEM699, Prereq: []
# Course: CHEM799, Prereq: []
# Course: CHEM889A, Prereq: []
# Course: CHEM889C, Prereq: []
# Course: CHEM889D, Prereq: []
# Course: CHEM889E, Prereq: []
# Course: CHEM889F, Prereq: []
# Course: CHEM889M, Prereq: []
# Course: CHEM898, Prereq: []
# Course: CHEM899, Prereq: []
# Course: CMSC100, Prereq: []
# Course: CMSC106, Prereq: ['MATH115']
# Course: CMSC122, Prereq: []
# Course: CMSC125, Prereq: ['MATH115']
# Course: CMSC131, Prereq: []
# Course: CMSC132, Prereq: ['CMSC131', 'MATH140']
# Course: CMSC133, Prereq: ['MATH140']
# Course: CMSC216, Prereq: ['CMSC132', 'MATH141']
# Course: CMSC250, Prereq: ['CMSC131', 'MATH141']
# Course: CMSC298A, Prereq: []
# Course: CMSC320, Prereq: ['CMSC216', 'CMSC250']
# Course: CMSC330, Prereq: ['CMSC250', 'CMSC216']
# Course: CMSC335, Prereq: ['CMSC216', 'CMSC250']
# Course: CMSC351, Prereq: ['CMSC250', 'CMSC216']
# Course: CMSC396H, Prereq: []
# Course: CMSC411, Prereq: ['CMSC330']
# Course: CMSC412, Prereq: ['CMSC330', 'CMSC351', 'CMSC414', 'CMSC417', 'CMSC420', 'CMSC430', 'CMSC433', 'CMSC435', 'ENEE440', 'ENEE457']
# Course: CMSC414, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC416, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC417, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC420, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC421, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC422, Prereq: ['CMSC320', 'CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC423, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC424, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC425, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC426, Prereq: ['CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC430, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC433, Prereq: ['CMSC330']
# Course: CMSC434, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC435, Prereq: ['CMSC412', 'CMSC417', 'CMSC420', 'CMSC430', 'CMSC433', 'ENEE447']
# Course: CMSC436, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC451, Prereq: ['CMSC351']
# Course: CMSC454, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC456, Prereq: ['CMSC106', 'CMSC131', 'ENEE150', 'CMSC330', 'CMSC351', 'ENEE324', 'ENEE380']
# Course: CMSC460, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340', 'CMSC106', 'CMSC131', 'MATH246']
# Course: CMSC466, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340', 'CMSC106', 'CMSC131', 'MATH410']
# Course: CMSC470, Prereq: ['CMSC320', 'CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC471, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC473, Prereq: ['CMSC421', 'CMSC422']
# Course: CMSC474, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC475, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340']
# Course: CMSC498A, Prereq: []
# Course: CMSC498B, Prereq: []
# Course: CMSC498J, Prereq: []
# Course: CMSC498K, Prereq: []
# Course: CMSC498Z, Prereq: []
# Course: CMSC499A, Prereq: []
# Course: CMSC616, Prereq: ['CMSC411', 'CMSC412']
# Course: CMSC631, Prereq: ['CMSC330']
# Course: CMSC634, Prereq: []
# Course: CMSC657, Prereq: []
# Course: CMSC660, Prereq: []
# Course: CMSC673, Prereq: ['CMSC421', 'CMSC422']
# Course: CMSC702, Prereq: []
# Course: CMSC723, Prereq: ['CMSC422']
# Course: CMSC740, Prereq: ['MATH240', 'CMSC420']
# Course: CMSC798, Prereq: []
# Course: CMSC799, Prereq: []
# Course: CMSC801, Prereq: []
# Course: CMSC818I, Prereq: []
# Course: CMSC818J, Prereq: []
# Course: CMSC818T, Prereq: []
# Course: CMSC818V, Prereq: []
# Course: CMSC828J, Prereq: []
# Course: CMSC828V, Prereq: []
# Course: CMSC838B, Prereq: []
# Course: CMSC838L, Prereq: []
# Course: CMSC839A, Prereq: []
# Course: CMSC839C, Prereq: []
# Course: CMSC839E, Prereq: []
# Course: CMSC848B, Prereq: []
# Course: CMSC848I, Prereq: []
# Course: CMSC848K, Prereq: []
# Course: CMSC848P, Prereq: []
# Course: CMSC858J, Prereq: []
# Course: CMSC858U, Prereq: []
# Course: CMSC898, Prereq: []
# Course: CMSC899, Prereq: []
# Course: ENCE100, Prereq: []
# Course: ENCE200, Prereq: ['ENES100', 'MATH141', 'ENES102']
# Course: ENCE201, Prereq: ['ENES220', 'MATH241']
# Course: ENCE205, Prereq: ['MATH140']
# Course: ENCE215, Prereq: ['CHEM135']
# Course: ENCE300, Prereq: ['ENES220']
# Course: ENCE302, Prereq: ['MATH246', 'ENCE201']
# Course: ENCE305, Prereq: ['ENES220', 'PHYS260', 'PHYS261']
# Course: ENCE310, Prereq: ['PHYS260', 'ENCE215']
# Course: ENCE320, Prereq: []
# Course: ENCE325, Prereq: []
# Course: ENCE340, Prereq: ['ENES220']
# Course: ENCE353, Prereq: ['MATH246', 'ENES220']
# Course: ENCE360, Prereq: ['ENCE201', 'MATH140']
# Course: ENCE370, Prereq: ['ENCE201', 'PHYS260', 'PHYS261']
# Course: ENCE411, Prereq: ['ENCE205', 'ENCE310']
# Course: ENCE422, Prereq: []
# Course: ENCE423, Prereq: []
# Course: ENCE424, Prereq: []
# Course: ENCE426, Prereq: []
# Course: ENCE432, Prereq: ['ENCE305']
# Course: ENCE433, Prereq: ['ENCE302']
# Course: ENCE441, Prereq: ['ENCE340']
# Course: ENCE444, Prereq: ['ENCE353', 'ENCE340']
# Course: ENCE454, Prereq: ['ENCE353']
# Course: ENCE465, Prereq: ['ENCE201', 'ENCE215']
# Course: ENCE470, Prereq: ['ENCE302', 'ENCE370']
# Course: ENCE489, Prereq: []
# Course: ENCE489L, Prereq: []
# Course: ENCE602, Prereq: []
# Course: ENCE607, Prereq: []
# Course: ENCE613, Prereq: []
# Course: ENCE614, Prereq: []
# Course: ENCE620, Prereq: ['ENCE302']
# Course: ENCE622, Prereq: []
# Course: ENCE627, Prereq: []
# Course: ENCE633, Prereq: ['ENCE302']
# Course: ENCE640, Prereq: ['ENCE340']
# Course: ENCE650, Prereq: []
# Course: ENCE651, Prereq: []
# Course: ENCE652, Prereq: []
# Course: ENCE662, Prereq: []
# Course: ENCE664, Prereq: []
# Course: ENCE666, Prereq: []
# Course: ENCE670, Prereq: []
# Course: ENCE672, Prereq: []
# Course: ENCE688B, Prereq: []
# Course: ENCE688I, Prereq: []
# Course: ENCE688T, Prereq: []
# Course: ENCE689, Prereq: []
# Course: ENCE799, Prereq: []
# Course: ENCE898, Prereq: []
# Course: ENCE899, Prereq: []
# Course: ENAE100, Prereq: []
# Course: ENAE202, Prereq: []
# Course: ENAE283, Prereq: ['PHYS161', 'MATH141', 'ENES102']
# Course: ENAE283H, Prereq: ['PHYS161', 'MATH141', 'ENES102']
# Course: ENAE301, Prereq: ['PHYS271', 'MATH461', 'PHYS270', 'MATH246', 'ENAE283', 'ENAE202', 'ENES102', 'MATH241']
# Course: ENAE311, Prereq: ['PHYS271', 'MATH240', 'MATH461', 'PHYS270', 'MATH246', 'ENAE283', 'ENES220', 'ENAE202', 'MATH241', 'ENES232']
# Course: ENAE311H, Prereq: ['PHYS271', 'MATH240', 'MATH461', 'PHYS270', 'MATH246', 'ENAE283', 'ENES220', 'ENAE202', 'MATH241', 'ENES232']
# Course: ENAE362, Prereq: ['MATH246', 'ENAE283']
# Course: ENAE380, Prereq: ['ENAE283', 'ENAE202']
# Course: ENAE398H, Prereq: []
# Course: ENAE403, Prereq: ['ENAE414', 'ENAE432']
# Course: ENAE414, Prereq: ['PHYS271', 'MATH240', 'MATH461', 'PHYS270', 'MATH246', 'ENAE283', 'ENES220', 'ENAE202', 'MATH241', 'ENES232']
# Course: ENAE423, Prereq: ['ENAE324']
# Course: ENAE423H, Prereq: ['ENAE324']
# Course: ENAE441, Prereq: ['ENAE404', 'ENAE432']
# Course: ENAE455, Prereq: ['ENES232', 'ENAE414', 'ENAE311']
# Course: ENAE457, Prereq: ['PHYS271', 'ENES232', 'PHYS270', 'ENAE311']
# Course: ENAE457H, Prereq: ['PHYS271', 'ENES232', 'PHYS270', 'ENAE311']
# Course: ENAE472, Prereq: ['ENAE311']
# Course: ENAE481, Prereq: ['ENAE324', 'ENAE362', 'ENAE432']
# Course: ENAE483, Prereq: ['ENAE404', 'ENAE324', 'ENAE362', 'ENAE432']
# Course: ENAE488G, Prereq: []
# Course: ENAE499, Prereq: []
# Course: ENAE601, Prereq: ['ENAE404']
# Course: ENAE603, Prereq: ['ENAE601']
# Course: ENAE631, Prereq: ['ENAE414', 'ENAE311']
# Course: ENAE636, Prereq: []
# Course: ENAE641, Prereq: ['ENAE432']
# Course: ENAE651, Prereq: []
# Course: ENAE655, Prereq: []
# Course: ENAE662, Prereq: ['ENES232', 'ENAE311']
# Course: ENAE673, Prereq: ['ENAE311', 'ENAE414', 'ENME331', 'ENME640']
# Course: ENAE681, Prereq: []
# Course: ENAE682, Prereq: []
# Course: ENAE684, Prereq: []
# Course: ENAE788D, Prereq: []
# Course: ENAE788G, Prereq: []
# Course: ENAE788L, Prereq: []
# Course: ENAE788X, Prereq: []
# Course: ENAE799, Prereq: []
# Course: ENAE898, Prereq: []
# Course: ENAE899, Prereq: []
# Course: ENEE101, Prereq: []
# Course: ENEE140, Prereq: []
# Course: ENEE150, Prereq: ['ENEE140', 'CMSC131']
# Course: ENEE200, Prereq: []
# Course: ENEE205, Prereq: ['PHYS260', 'PHYS261']
# Course: ENEE222, Prereq: ['ENEE140', 'CMSC131']
# Course: ENEE244, Prereq: ['CMSC132', 'ENEE150']
# Course: ENEE245, Prereq: ['ENEE244', 'ENEE150', 'CMSC132']
# Course: ENEE290, Prereq: ['MATH141']
# Course: ENEE304, Prereq: ['ENEE205']
# Course: ENEE305, Prereq: ['ENEE304']
# Course: ENEE322, Prereq: ['MATH246', 'ENEE290', 'ENEE222']
# Course: ENEE323, Prereq: ['MATH246', 'ENEE290', 'ENEE222']
# Course: ENEE324, Prereq: ['MATH246', 'ENEE222']
# Course: ENEE350, Prereq: ['ENEE244', 'ENEE150', 'CMSC132']
# Course: ENEE382, Prereq: ['ENEE205', 'MATH241', 'PHYS270', 'PHYS271']
# Course: ENEE408A, Prereq: []
# Course: ENEE408C, Prereq: []
# Course: ENEE408I, Prereq: []
# Course: ENEE408V, Prereq: []
# Course: ENEE411, Prereq: ['ENEE303', 'ENEE304']
# Course: ENEE416, Prereq: ['ENEE303', 'ENEE304']
# Course: ENEE420, Prereq: ['ENEE322', 'ENEE323', 'ENEE324']
# Course: ENEE425, Prereq: ['ENEE322', 'ENEE323']
# Course: ENEE428, Prereq: []
# Course: ENEE429Z, Prereq: []
# Course: ENEE436, Prereq: ['ENEE324', 'STAT400', 'ENEE150', 'CMSC216']
# Course: ENEE439Q, Prereq: []
# Course: ENEE440, Prereq: ['ENEE350']
# Course: ENEE445, Prereq: ['ENEE205', 'ENEE350']
# Course: ENEE446, Prereq: ['ENEE350']
# Course: ENEE457, Prereq: ['ENEE350']
# Course: ENEE459A, Prereq: []
# Course: ENEE459B, Prereq: []
# Course: ENEE460, Prereq: ['ENEE322', 'ENEE290', 'MATH240', 'MATH461']
# Course: ENEE467, Prereq: ['ENAE450']
# Course: ENEE474, Prereq: ['ENEE322', 'ENEE323']
# Course: ENEE476, Prereq: ['ENEE303', 'ENEE304']
# Course: ENEE484, Prereq: []
# Course: ENEE486, Prereq: ['ENEE205', 'ENEE206', 'PHYS271', 'PHYS270']
# Course: ENEE488, Prereq: []
# Course: ENEE489R, Prereq: []
# Course: ENEE489W, Prereq: []
# Course: ENEE499, Prereq: []
# Course: ENEE499H, Prereq: []
# Course: ENEE600, Prereq: ['ENEE413']
# Course: ENEE611, Prereq: []
# Course: ENEE620, Prereq: ['ENEE324']
# Course: ENEE630, Prereq: ['ENEE425']
# Course: ENEE634, Prereq: ['ENEE620', 'ENEE630']
# Course: ENEE641, Prereq: []
# Course: ENEE646, Prereq: ['ENEE446']
# Course: ENEE660, Prereq: ['ENEE460', 'MATH463']
# Course: ENEE662, Prereq: []
# Course: ENEE680, Prereq: ['ENEE381']
# Course: ENEE690, Prereq: ['ENEE381']
# Course: ENEE698Q, Prereq: []
# Course: ENEE699, Prereq: []
# Course: ENEE719D, Prereq: []
# Course: ENEE739F, Prereq: []
# Course: ENEE739Z, Prereq: []
# Course: ENEE759C, Prereq: []
# Course: ENEE765, Prereq: ['ENEE660', 'ENEE664']
# Course: ENEE789D, Prereq: []
# Course: ENEE789W, Prereq: []
# Course: ENEE799, Prereq: []
# Course: ENEE898, Prereq: []
# Course: ENEE899, Prereq: []
# Course: ENFP101, Prereq: []
# Course: ENFP250, Prereq: []
# Course: ENFP300, Prereq: ['MATH246', 'ENFP201', 'PHYS260', 'PHYS261']
# Course: ENFP405, Prereq: ['ENES220']
# Course: ENFP410, Prereq: ['ENFP310', 'ENFP312']
# Course: ENFP415, Prereq: ['ENFP312']
# Course: ENFP425, Prereq: ['ENES232', 'ENFP300', 'ENFP312']
# Course: ENFP429, Prereq: []
# Course: ENFP440, Prereq: ['ENFP300']
# Course: ENFP467, Prereq: ['ENFP312']
# Course: ENFP489, Prereq: []
# Course: ENFP601, Prereq: []
# Course: ENFP610, Prereq: []
# Course: ENFP619, Prereq: []
# Course: ENFP621, Prereq: ['ENFP312']
# Course: ENFP626, Prereq: ['ENFP300', 'ENFP312']
# Course: ENFP627, Prereq: ['ENFP300']
# Course: ENFP629, Prereq: []
# Course: ENFP630, Prereq: ['ENFP312']
# Course: ENFP649, Prereq: []
# Course: ENFP651, Prereq: ['ENFP312']
# Course: ENFP653, Prereq: []
# Course: ENFP664, Prereq: []
# Course: ENFP667, Prereq: ['ENFP312']
# Course: ENFP799, Prereq: []
# Course: ENMA180, Prereq: []
# Course: ENMA300, Prereq: ['ENES100']
# Course: ENMA312, Prereq: ['ENMA300']
# Course: ENMA362, Prereq: ['ENMA300']
# Course: ENMA414, Prereq: ['ENMA300']
# Course: ENMA422, Prereq: ['ENMA300']
# Course: ENMA437, Prereq: ['MATH206', 'ENMA300', 'MATH461']
# Course: ENMA441, Prereq: ['ENMA300', 'ENMA165', 'MATH206']
# Course: ENMA460, Prereq: ['PHYS271', 'PHYS270', 'MATH241']
# Course: ENMA464, Prereq: ['ENMA300']
# Course: ENMA466, Prereq: ['ENMA465']
# Course: ENMA471, Prereq: ['ENMA461']
# Course: ENMA473, Prereq: ['ENMA300', 'ENMA362', 'ENMA461']
# Course: ENMA486, Prereq: []
# Course: ENMA487, Prereq: []
# Course: ENMA499, Prereq: []
# Course: ENMA613, Prereq: []
# Course: ENMA614, Prereq: []
# Course: ENMA637, Prereq: ['MATH461']
# Course: ENMA641, Prereq: []
# Course: ENMA650, Prereq: ['ENMA460']
# Course: ENMA660, Prereq: []
# Course: ENMA664, Prereq: []
# Course: ENMA688, Prereq: []
# Course: ENMA698, Prereq: []
# Course: ENMA797, Prereq: []
# Course: ENMA799, Prereq: []
# Course: ENMA898, Prereq: []
# Course: ENMA899, Prereq: []
# Course: ENME202, Prereq: []
# Course: ENME208, Prereq: []
# Course: ENME272, Prereq: ['MATH141']
# Course: ENME299Z, Prereq: []
# Course: ENME331, Prereq: ['ENES232', 'ENES221']
# Course: ENME332, Prereq: ['ENME331']
# Course: ENME350, Prereq: ['PHYS271', 'PHYS270']
# Course: ENME351, Prereq: ['PHYS271', 'ENME350', 'PHYS270']
# Course: ENME361, Prereq: ['ENES220', 'ENES221', 'MATH246', 'MATH206', 'ENME202']
# Course: ENME371, Prereq: ['ENES221', 'ENME392', 'STAT400']
# Course: ENME382, Prereq: ['ENES100']
# Course: ENME392, Prereq: ['MATH241']
# Course: ENME400, Prereq: ['ENME361']
# Course: ENME401, Prereq: []
# Course: ENME408, Prereq: []
# Course: ENME416, Prereq: ['ENME331', 'ENME272', 'ENME414']
# Course: ENME422, Prereq: ['ENES232', 'ENME332']
# Course: ENME423, Prereq: ['ENES232']
# Course: ENME425, Prereq: ['ENES232']
# Course: ENME426, Prereq: []
# Course: ENME430, Prereq: ['MATH246']
# Course: ENME432, Prereq: ['ENME430', 'MATH246']
# Course: ENME434, Prereq: ['PHYS270', 'MATH141']
# Course: ENME440, Prereq: ['ENME392']
# Course: ENME441, Prereq: ['ENME351']
# Course: ENME444, Prereq: ['ENME351', 'ENME462']
# Course: ENME454, Prereq: []
# Course: ENME462, Prereq: ['ENME361']
# Course: ENME467, Prereq: []
# Course: ENME470, Prereq: []
# Course: ENME472, Prereq: ['ENME331', 'ENME361', 'ENME351', 'ENME371', 'ENME332']
# Course: ENME473, Prereq: ['ENME351']
# Course: ENME480, Prereq: ['MATH246', 'ENES221', 'CMSC131', 'ENME202', 'ENAE202', 'ENEE150']
# Course: ENME488, Prereq: []
# Course: ENME489, Prereq: []
# Course: ENME489F, Prereq: []
# Course: ENME489O, Prereq: []
# Course: ENME489U, Prereq: []
# Course: ENME489V, Prereq: []
# Course: ENME605, Prereq: ['ENME462']
# Course: ENME610, Prereq: []
# Course: ENME631, Prereq: ['ENME332']
# Course: ENME640, Prereq: []
# Course: ENME645, Prereq: ['ENME331', 'ENME361']
# Course: ENME662, Prereq: []
# Course: ENME690, Prereq: ['ENME351']
# Course: ENME691, Prereq: ['ENME202']
# Course: ENME692, Prereq: ['PHYS270', 'MATH141']
# Course: ENME694, Prereq: []
# Course: ENME722, Prereq: []
# Course: ENME737, Prereq: []
# Course: ENME743, Prereq: ['ENME392']
# Course: ENME744, Prereq: ['ENME272', 'ENME331', 'ENME416']
# Course: ENME750, Prereq: []
# Course: ENME753, Prereq: []
# Course: ENME799, Prereq: []
# Course: ENME808, Prereq: []
# Course: ENME808Q, Prereq: []
# Course: ENME898, Prereq: []
# Course: ENME899, Prereq: []
# Course: ENSP101, Prereq: []
# Course: ENSP305, Prereq: ['GEOG373']
# Course: ENSP330, Prereq: []
# Course: ENSP340, Prereq: []
# Course: ENSP386, Prereq: []
# Course: ENSP399, Prereq: []
# Course: ENSP399N, Prereq: []
# Course: ENSP399R, Prereq: []
# Course: ENSP400, Prereq: ['ENSP101', 'ENSP102']
# Course: ENSP499, Prereq: []
# Course: ENST101, Prereq: []
# Course: ENST115, Prereq: []
# Course: ENST200, Prereq: []
# Course: ENST233, Prereq: []
# Course: ENST281, Prereq: []
# Course: ENST282, Prereq: []
# Course: ENST301, Prereq: []
# Course: ENST302, Prereq: ['ENST301']
# Course: ENST303, Prereq: ['ENST302']
# Course: ENST333, Prereq: ['ENST233']
# Course: ENST360, Prereq: ['BSCI160', 'BSCI161', 'BSCI106']
# Course: ENST388, Prereq: []
# Course: ENST389, Prereq: []
# Course: ENST403, Prereq: []
# Course: ENST411, Prereq: ['ENST200']
# Course: ENST414, Prereq: ['ENST200']
# Course: ENST415, Prereq: ['CHEM131', 'PHYS121', 'MATH113']
# Course: ENST417, Prereq: ['ENST200', 'MATH113', 'MATH115']
# Course: ENST432, Prereq: ['CHEM131', 'CHEM132']
# Course: ENST441, Prereq: []
# Course: ENST450, Prereq: ['BIOM301', 'ENST360']
# Course: ENST456, Prereq: []
# Course: ENST460, Prereq: ['ENST360', 'BSCI361']
# Course: ENST472, Prereq: []
# Course: ENST485, Prereq: ['MATH120', 'MATH130', 'MATH136', 'MATH140']
# Course: ENST486, Prereq: ['ENST389']
# Course: ENST489, Prereq: []
# Course: ENST499, Prereq: []
# Course: ENST499A, Prereq: []
# Course: ENST499E, Prereq: []
# Course: ENST499L, Prereq: []
# Course: ENST499X, Prereq: []
# Course: ENST499Y, Prereq: []
# Course: ENST602, Prereq: []
# Course: ENST603, Prereq: []
# Course: ENST606, Prereq: []
# Course: ENST611, Prereq: ['ENST200']
# Course: ENST650, Prereq: ['BIOM301', 'ENST360']
# Course: ENST689, Prereq: []
# Course: ENST689M, Prereq: []
# Course: ENST689X, Prereq: []
# Course: ENST689Y, Prereq: []
# Course: ENST689Z, Prereq: []
# Course: ENST761, Prereq: ['ENST414']
# Course: ENST798, Prereq: []
# Course: ENST799, Prereq: []
# Course: ENST898, Prereq: []
# Course: ENST899, Prereq: []
# Course: ENTM699K, Prereq: []
# Course: ENTM701, Prereq: []
# Course: ENTM788C, Prereq: []
# Course: ENTM798T, Prereq: []
# Course: ENTM799, Prereq: []
# Course: ENTM898, Prereq: []
# Course: ENTM899, Prereq: []
# Course: GEOG140, Prereq: []
# Course: GEOG156, Prereq: []
# Course: GEOG170, Prereq: []
# Course: GEOG172, Prereq: []
# Course: GEOG201, Prereq: []
# Course: GEOG202, Prereq: []
# Course: GEOG211, Prereq: ['GEOL120', 'GEOL100', 'GEOG201']
# Course: GEOG272, Prereq: []
# Course: GEOG276, Prereq: []
# Course: GEOG330, Prereq: []
# Course: GEOG371, Prereq: ['GEOG276', 'GEOG306', 'GEOG272']
# Course: GEOG373, Prereq: []
# Course: GEOG384, Prereq: ['GEOG211', 'GEOG306', 'GEOG212', 'GEOG201', 'ENGL393', 'ENGL390']
# Course: GEOG385, Prereq: ['GEOG211', 'GEOG306', 'GEOG212', 'GEOG201']
# Course: GEOG398, Prereq: []
# Course: GEOG416, Prereq: []
# Course: GEOG417, Prereq: ['GEOG272', 'GEOG306']
# Course: GEOG418, Prereq: []
# Course: GEOG440, Prereq: ['PHYS171', 'PHYS161', 'AOSC401', 'GEOG301']
# Course: GEOG475, Prereq: ['GEOG373', 'GEOG306']
# Course: GEOG498, Prereq: []
# Course: GEOG498G, Prereq: []
# Course: GEOG498N, Prereq: []
# Course: GEOG601, Prereq: []
# Course: GEOG608, Prereq: []
# Course: GEOG617, Prereq: []
# Course: GEOG652, Prereq: []
# Course: GEOG653, Prereq: ['GEOG579']
# Course: GEOG654, Prereq: ['GEOG653']
# Course: GEOG661, Prereq: []
# Course: GEOG662, Prereq: []
# Course: GEOG686, Prereq: []
# Course: GEOG688M, Prereq: []
# Course: GEOG788, Prereq: []
# Course: GEOG788F, Prereq: []
# Course: GEOG788L, Prereq: []
# Course: GEOG788P, Prereq: []
# Course: GEOG788Z, Prereq: []
# Course: GEOG789, Prereq: []
# Course: GEOG790, Prereq: []
# Course: GEOG797, Prereq: []
# Course: GEOG798, Prereq: []
# Course: GEOG799, Prereq: []
# Course: GEOG898, Prereq: []
# Course: GEOG899, Prereq: []
# Course: GEOL100, Prereq: []
# Course: GEOL104, Prereq: []
# Course: GEOL110, Prereq: ['GEOL120', 'GEOL100']
# Course: GEOL120, Prereq: []
# Course: GEOL123, Prereq: []
# Course: GEOL200, Prereq: []
# Course: GEOL212, Prereq: []
# Course: GEOL341, Prereq: ['GEOL120', 'GEOL100', 'GEOL102', 'GEOL110']
# Course: GEOL342, Prereq: ['GEOL120', 'GEOL100', 'GEOL110', 'GEOL322', 'CHEM103', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL375, Prereq: ['MATH120']
# Course: GEOL386, Prereq: []
# Course: GEOL393, Prereq: ['PHYS141', 'PHYS161', 'PHYS174', 'MATH141', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL394, Prereq: ['GEOL393']
# Course: GEOL413, Prereq: ['MATH115']
# Course: GEOL423, Prereq: ['GEOL100', 'GEOL120', 'GEOL110', 'GEOL322', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM103']
# Course: GEOL436, Prereq: ['MATH120', 'MATH140', 'MATH220', 'GEOL100', 'GEOL120', 'GEOL322', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL444, Prereq: ['GEOL322', 'GEOL100', 'MATH115', 'CHEM103', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL446, Prereq: ['PHYS141', 'MATH141', 'MATH140', 'GEOL100', 'GEOL120']
# Course: GEOL451, Prereq: ['GEOL110', 'MATH140', 'GEOL120', 'GEOL100', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM103']
# Course: GEOL452, Prereq: []
# Course: GEOL453, Prereq: ['MATH120', 'MATH140', 'MATH220', 'CHEM131', 'CHEM135', 'CHEM132', 'CHEM136', 'GEOL100', 'GEOL120', 'ENST200']
# Course: GEOL460, Prereq: ['GEOL100', 'GEOL120', 'MATH140', 'MATH141', 'PHYS141', 'PHYS161', 'PHYS171']
# Course: GEOL488, Prereq: []
# Course: GEOL499, Prereq: []
# Course: GEOL613, Prereq: ['MATH115']
# Course: GEOL636, Prereq: ['MATH120', 'MATH140', 'CHEM131', 'CHEM135', 'CHEM132', 'CHEM136', 'GEOL100', 'GEOL120', 'ENST200']
# Course: GEOL650, Prereq: ['GEOL443']
# Course: GEOL652, Prereq: ['GEOL452']
# Course: GEOL670, Prereq: []
# Course: GEOL688, Prereq: []
# Course: GEOL789C, Prereq: []
# Course: GEOL789F, Prereq: []
# Course: GEOL798, Prereq: []
# Course: GEOL799, Prereq: []
# Course: GEOL898, Prereq: []
# Course: GEOL899, Prereq: []
# Course: MATH003, Prereq: []
# Course: MATH007, Prereq: []
# Course: MATH013, Prereq: []
# Course: MATH015, Prereq: []
# Course: MATH107, Prereq: ['MATH107', 'MATH003']
# Course: MATH113, Prereq: ['MATH113']
# Course: MATH115, Prereq: ['MATH115', 'MATH003', 'MATH113']
# Course: MATH120, Prereq: ['MATH113', 'MATH115', 'MATH120']
# Course: MATH121, Prereq: ['MATH120', 'MATH130', 'MATH136', 'MATH140']
# Course: MATH135, Prereq: ['MATH113', 'MATH115', 'MATH120']
# Course: MATH136, Prereq: ['MATH135']
# Course: MATH140, Prereq: ['MATH115']
# Course: MATH140H, Prereq: ['MATH115']
# Course: MATH141, Prereq: ['MATH140']
# Course: MATH141H, Prereq: ['MATH140']
# Course: MATH206, Prereq: ['MATH136', 'MATH140']
# Course: MATH212, Prereq: []
# Course: MATH213, Prereq: ['MATH212']
# Course: MATH214, Prereq: ['MATH212']
# Course: MATH240, Prereq: ['MATH131', 'MATH141']
# Course: MATH241, Prereq: ['MATH141']
# Course: MATH241H, Prereq: ['MATH141']
# Course: MATH243, Prereq: ['MATH141']
# Course: MATH246, Prereq: ['MATH141']
# Course: MATH246H, Prereq: ['MATH141']
# Course: MATH274, Prereq: ['MATH120', 'MATH130', 'MATH136', 'MATH140', 'MATH220']
# Course: MATH299B, Prereq: []
# Course: MATH310, Prereq: ['MATH141', 'MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340']
# Course: MATH312, Prereq: ['MATH212', 'MATH213']
# Course: MATH315, Prereq: ['MATH212']
# Course: MATH340, Prereq: ['MATH141', 'MATH140']
# Course: MATH386, Prereq: []
# Course: MATH401, Prereq: ['MATH461', 'MATH240', 'MATH341']
# Course: MATH402, Prereq: ['MATH240', 'MATH341', 'MATH461']
# Course: MATH403, Prereq: ['MATH240', 'MATH461', 'MATH340', 'MATH341', 'MATH241', 'MATH310']
# Course: MATH405, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH310']
# Course: MATH406, Prereq: ['MATH240', 'MATH241', 'MATH246', 'MATH340', 'MATH341', 'MATH461']
# Course: MATH407, Prereq: []
# Course: MATH410, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH340', 'MATH241', 'MATH310']
# Course: MATH411, Prereq: ['MATH410']
# Course: MATH416, Prereq: ['MATH141', 'MATH240', 'MATH461', 'MATH341']
# Course: MATH423, Prereq: ['MATH240', 'MATH401', 'MATH461', 'MATH341']
# Course: MATH424, Prereq: ['MATH141', 'STAT400', 'STAT410']
# Course: MATH430, Prereq: ['MATH240', 'MATH341', 'MATH461']
# Course: MATH431, Prereq: ['MATH461', 'MATH240', 'MATH341']
# Course: MATH432, Prereq: ['MATH410']
# Course: MATH436, Prereq: ['MATH241', 'MATH340', 'MATH461', 'MATH240', 'MATH341', 'MATH461']
# Course: MATH445, Prereq: ['MATH141']
# Course: MATH456, Prereq: ['CMSC106', 'CMSC131', 'ENEE150', 'CMSC330', 'CMSC351', 'ENEE324', 'ENEE380']
# Course: MATH461, Prereq: ['MATH141', 'MATH141']
# Course: MATH462, Prereq: ['MATH241', 'MATH340', 'MATH246', 'MATH341']
# Course: MATH463, Prereq: ['MATH241', 'MATH340']
# Course: MATH464, Prereq: ['MATH246', 'MATH341']
# Course: MATH475, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340']
# Course: MATH489, Prereq: []
# Course: MATH498A, Prereq: []
# Course: MATH600, Prereq: ['MATH405', 'MATH403']
# Course: MATH602, Prereq: ['MATH600']
# Course: MATH606, Prereq: ['MATH600', 'MATH601']
# Course: MATH630, Prereq: ['MATH411']
# Course: MATH634, Prereq: ['MATH630']
# Course: MATH642, Prereq: ['MATH432', 'MATH630']
# Course: MATH669, Prereq: []
# Course: MATH673, Prereq: ['MATH411']
# Course: MATH689, Prereq: []
# Course: MATH695, Prereq: []
# Course: MATH712, Prereq: []
# Course: MATH730, Prereq: ['MATH403', 'MATH410', 'MATH411']
# Course: MATH742, Prereq: ['MATH673', 'MATH674', 'MATH740']
# Course: MATH799, Prereq: []
# Course: MATH808A, Prereq: []
# Course: MATH808J, Prereq: []
# Course: MATH808L, Prereq: []
# Course: MATH818A, Prereq: []
# Course: MATH818T, Prereq: []
# Course: MATH838D, Prereq: []
# Course: MATH848A, Prereq: []
# Course: MATH848N, Prereq: []
# Course: MATH848T, Prereq: []
# Course: MATH858A, Prereq: []
# Course: MATH858I, Prereq: []
# Course: MATH868A, Prereq: []
# Course: MATH898, Prereq: []
# Course: MATH899, Prereq: []
# Course: NEUR200, Prereq: ['BSCI170', 'BSCI171']
# Course: NEUR305, Prereq: ['MATH120', 'NEUR200', 'BSCI353']
# Course: NEUR306, Prereq: ['NEUR200', 'BSCI207', 'BSCI330']
# Course: NEUR329, Prereq: []
# Course: NEUR379, Prereq: []
# Course: NEUR379H, Prereq: []
# Course: NEUR398H, Prereq: []
# Course: NEUR405, Prereq: ['NEUR306', 'BSCI353', 'PHYS132']
# Course: NEUR479, Prereq: []
# Course: NEUR479H, Prereq: []
# Course: PHYS102, Prereq: ['MATH107']
# Course: PHYS103, Prereq: []
# Course: PHYS105, Prereq: []
# Course: PHYS115, Prereq: []
# Course: PHYS121, Prereq: ['MATH113', 'MATH115']
# Course: PHYS122, Prereq: ['PHYS121']
# Course: PHYS131, Prereq: ['CHEM131', 'MATH136', 'MATH140', 'BSCI160', 'BSCI161', 'BSCI106', 'BSCI170', 'BSCI171', 'BSCI105']
# Course: PHYS132, Prereq: ['PHYS131']
# Course: PHYS161, Prereq: ['MATH141']
# Course: PHYS170, Prereq: []
# Course: PHYS171, Prereq: ['MATH140']
# Course: PHYS171H, Prereq: ['MATH140']
# Course: PHYS172, Prereq: []
# Course: PHYS174, Prereq: []
# Course: PHYS235, Prereq: []
# Course: PHYS260, Prereq: ['PHYS161', 'MATH141']
# Course: PHYS260H, Prereq: ['PHYS161', 'MATH141']
# Course: PHYS261, Prereq: ['PHYS161']
# Course: PHYS265, Prereq: ['PHYS171', 'PHYS141', 'PHYS161']
# Course: PHYS270, Prereq: ['PHYS261', 'MATH241', 'PHYS260']
# Course: PHYS271, Prereq: ['PHYS261']
# Course: PHYS272, Prereq: ['PHYS161', 'PHYS171', 'MATH141', 'MATH241']
# Course: PHYS272H, Prereq: ['PHYS161', 'PHYS171', 'MATH141', 'MATH241']
# Course: PHYS273, Prereq: ['MATH241', 'PHYS272', 'PHYS274', 'MATH243', 'MATH246']
# Course: PHYS273H, Prereq: ['MATH241', 'PHYS272', 'PHYS274', 'MATH243', 'MATH246']
# Course: PHYS275, Prereq: ['PHYS171', 'PHYS161']
# Course: PHYS276, Prereq: ['PHYS272', 'PHYS275']
# Course: PHYS299, Prereq: []
# Course: PHYS299E, Prereq: []
# Course: PHYS299W, Prereq: []
# Course: PHYS313, Prereq: ['MATH241', 'PHYS273', 'PHYS274', 'MATH240', 'MATH243', 'MATH246']
# Course: PHYS331, Prereq: ['CHEM131', 'MATH131', 'MATH136', 'BSCI160', 'BSCI161', 'BSCI106', 'BSCI170', 'BSCI171', 'BSCI105']
# Course: PHYS371, Prereq: ['PHYS273', 'PHYS274', 'MATH243', 'MATH246']
# Course: PHYS375, Prereq: ['PHYS276', 'PHYS273']
# Course: PHYS386, Prereq: []
# Course: PHYS389, Prereq: []
# Course: PHYS398, Prereq: []
# Course: PHYS399, Prereq: []
# Course: PHYS401, Prereq: ['PHYS371', 'PHYS313', 'PHYS373']
# Course: PHYS402, Prereq: ['PHYS401']
# Course: PHYS404, Prereq: ['PHYS371', 'PHYS420']
# Course: PHYS405, Prereq: ['PHYS375']
# Course: PHYS407, Prereq: ['PHYS499', 'PHYS375']
# Course: PHYS410, Prereq: ['PHYS265', 'PHYS273', 'MATH243', 'MATH246']
# Course: PHYS413, Prereq: ['PHYS313', 'PHYS412']
# Course: PHYS431, Prereq: ['PHYS271', 'PHYS270', 'MATH241']
# Course: PHYS467, Prereq: ['MATH141', 'MATH240', 'PHYS360', 'PHYS401', 'PHYS457', 'ENEE491']
# Course: PHYS485, Prereq: ['PHYS272', 'PHYS276']
# Course: PHYS488P, Prereq: []
# Course: PHYS499A, Prereq: []
# Course: PHYS499B, Prereq: []
# Course: PHYS499V, Prereq: []
# Course: PHYS610, Prereq: []
# Course: PHYS612, Prereq: []
# Course: PHYS624, Prereq: ['PHYS613', 'PHYS623']
# Course: PHYS625, Prereq: ['PHYS612', 'PHYS613']
# Course: PHYS675, Prereq: ['PHYS606', 'PHYS601']
# Course: PHYS685, Prereq: []
# Course: PHYS688P, Prereq: []
# Course: PHYS709, Prereq: []
# Course: PHYS715, Prereq: ['PHYS601']
# Course: PHYS728J, Prereq: []
# Course: PHYS738, Prereq: []
# Course: PHYS739, Prereq: []
# Course: PHYS749, Prereq: []
# Course: PHYS758E, Prereq: []
# Course: PHYS759, Prereq: []
# Course: PHYS761, Prereq: ['PHYS606', 'PHYS604']
# Course: PHYS769, Prereq: []
# Course: PHYS778, Prereq: []
# Course: PHYS798, Prereq: []
# Course: PHYS798B, Prereq: []
# Course: PHYS798L, Prereq: []
# Course: PHYS798Q, Prereq: []
# Course: PHYS799, Prereq: []
# Course: PHYS838C, Prereq: []
# Course: PHYS839A, Prereq: []
# Course: PHYS859C, Prereq: []
# Course: PHYS898, Prereq: []
# Course: PHYS899, Prereq: []
# Course: PLSC115, Prereq: []
# Course: PLSC201, Prereq: ['PLSC110', 'PLSC111', 'PLSC112', 'PLSC113', 'CHEM131', 'CHEM132']
# Course: PLSC203, Prereq: ['BSCI103', 'BSCI170', 'BSCI171']
# Course: PLSC205, Prereq: []
# Course: PLSC206, Prereq: ['PLSC201']
# Course: PLSC253, Prereq: ['PLSC110', 'PLSC111']
# Course: PLSC389, Prereq: []
# Course: PLSC399, Prereq: []
# Course: PLSC404, Prereq: ['BSCI170', 'BSCI171', 'PLSC201', 'PLSC206']
# Course: PLSC420, Prereq: ['CHEM131', 'CHEM132', 'PLSC201']
# Course: PLSC433, Prereq: ['PLSC201', 'PLSC271', 'ENST200']
# Course: PLSC489E, Prereq: []
# Course: PLSC489R, Prereq: []
# Course: PLSC608, Prereq: []
# Course: PLSC608T, Prereq: []
# Course: PLSC799, Prereq: []
# Course: PLSC898, Prereq: []
# Course: PLSC899, Prereq: []
# Course: STAT100, Prereq: ['MATH110', 'MATH112', 'MATH113', 'MATH115', 'STAT100']
# Course: STAT110, Prereq: ['DATA100', 'STAT100', 'MATH135']
# Course: STAT386, Prereq: []
# Course: STAT400, Prereq: ['MATH131', 'MATH141']
# Course: STAT401, Prereq: ['STAT400', 'STAT410']
# Course: STAT410, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH340', 'MATH241']
# Course: STAT420, Prereq: ['SURV410', 'STAT410']
# Course: STAT426, Prereq: ['MATH241', 'MATH340', 'MATH240', 'MATH461', 'MATH341', 'STAT400', 'STAT410', 'STAT400']
# Course: STAT430, Prereq: ['STAT400', 'STAT410', 'STAT401', 'STAT420', 'STAT401', 'STAT420']
# Course: STAT440, Prereq: ['STAT401', 'STAT420']
# Course: STAT464, Prereq: []
# Course: STAT470, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH340', 'MATH241']
# Course: STAT498A, Prereq: []
# Course: STAT600, Prereq: ['STAT410']
# Course: STAT689, Prereq: []
# Course: STAT700, Prereq: ['STAT410']
# Course: STAT702, Prereq: ['STAT410', 'STAT420']
# Course: STAT705, Prereq: ['STAT700', 'STAT420']
# Course: STAT740, Prereq: ['STAT700', 'STAT420']
# Course: STAT799, Prereq: []
# Course: STAT808A, Prereq: []
# Course: STAT818A, Prereq: []
# Course: STAT818E, Prereq: []
# Course: STAT818T, Prereq: []
# Course: STAT898, Prereq: []
# Course: STAT899, Prereq: []
# Course: INST101, Prereq: []
# Course: INST104, Prereq: []
# Course: INST123, Prereq: []
# Course: INST126, Prereq: ['STAT100']
# Course: INST151, Prereq: []
# Course: INST152, Prereq: []
# Course: INST153, Prereq: []
# Course: INST154, Prereq: []
# Course: INST155, Prereq: []
# Course: INST156, Prereq: []
# Course: INST201, Prereq: []
# Course: INST204, Prereq: []
# Course: INST204S, Prereq: []
# Course: INST210, Prereq: []
# Course: INST227, Prereq: []
# Course: INST228, Prereq: []
# Course: INST301, Prereq: []
# Course: INST309, Prereq: []
# Course: INST311, Prereq: ['PSYC100', 'SOCY105']
# Course: INST314, Prereq: ['INST126', 'GEOG276', 'STAT100', 'MATH115']
# Course: INST320, Prereq: []
# Course: INST326, Prereq: ['INST126', 'GEOG276']
# Course: INST327, Prereq: ['INST126', 'GEOG276']
# Course: INST335, Prereq: ['INST201', 'INST301', 'PSYC100']
# Course: INST341, Prereq: ['INST311']
# Course: INST346, Prereq: ['INST201', 'INST301', 'INST326', 'INST327']
# Course: INST347, Prereq: ['INST346']
# Course: INST352, Prereq: ['INST201', 'INST301', 'INST311']
# Course: INST354, Prereq: ['INST201', 'INST301', 'INST314', 'PSYC100']
# Course: INST362, Prereq: ['INST201', 'INST301', 'PSYC100', 'SOCY105', 'INST326', 'STAT100']
# Course: INST363, Prereq: []
# Course: INST364, Prereq: ['INST201', 'INST301', 'INST327', 'STAT100', 'MATH115', 'PSYC100']
# Course: INST366, Prereq: ['INST126', 'GEOG276', 'STAT100', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'SOCY105']
# Course: INST367, Prereq: ['INST380']
# Course: INST377, Prereq: ['INST201', 'INST301', 'BSOS233', 'INST327', 'STAT100', 'MATH115']
# Course: INST380, Prereq: ['INST201', 'INST126', 'STAT100', 'PSYC100', 'SOCY105']
# Course: INST381, Prereq: ['PSYC100', 'SOCY105', 'INST126', 'INST201', 'STAT100', 'MATH115']
# Course: INST388E, Prereq: []
# Course: INST388F, Prereq: []
# Course: INST402, Prereq: ['INST362', 'INST367']
# Course: INST405, Prereq: ['INST126', 'STAT100', 'INST201', 'PSYC100', 'SOCY105']
# Course: INST406, Prereq: ['INST380']
# Course: INST407, Prereq: []
# Course: INST408I, Prereq: []
# Course: INST408R, Prereq: []
# Course: INST408V, Prereq: []
# Course: INST408Z, Prereq: []
# Course: INST410, Prereq: ['INST126', 'STAT100', 'PSYC100', 'SOCY105', 'INST201', 'INST301', 'MATH115']
# Course: INST414, Prereq: ['MATH115', 'STAT100', 'INST126', 'GEOG276', 'INST201', 'INST301', 'BSOS233', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'BSOS233', 'INST314']
# Course: INST441, Prereq: ['INST341', 'INST380']
# Course: INST442, Prereq: ['INST341', 'INST380']
# Course: INST447, Prereq: ['STAT100', 'INST327', 'INST201', 'INST301', 'BSOS233', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'BSOS233', 'INST314', 'BSOS331', 'GEOG273', 'INST326']
# Course: INST451, Prereq: ['INST126', 'INST201', 'STAT100', 'PSYC100', 'SOCY105']
# Course: INST453, Prereq: []
# Course: INST454, Prereq: ['INST104', 'INST126', 'INST204', 'INST380', 'INST367']
# Course: INST455, Prereq: []
# Course: INST461, Prereq: []
# Course: INST462, Prereq: ['STAT100', 'INST201', 'INST301', 'BSOS233', 'INST126', 'GEOG276', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'SOCY105', 'BSOS233', 'INST314']
# Course: INST464, Prereq: ['INST201', 'INST126', 'MATH115', 'PSYC100', 'INST364']
# Course: INST466, Prereq: ['INST201', 'INST301', 'PSYC100', 'SOCY105']
# Course: INST490, Prereq: ['INST311', 'INST314', 'INST326', 'INST327', 'INST335', 'INST346', 'INST352', 'INST362']
# Course: INST600, Prereq: []
# Course: INST604, Prereq: []
# Course: INST607, Prereq: []
# Course: INST608Q, Prereq: []
# Course: INST610, Prereq: []
# Course: INST611, Prereq: []
# Course: INST613, Prereq: []
# Course: INST615, Prereq: []
# Course: INST620, Prereq: []
# Course: INST627, Prereq: []
# Course: INST630, Prereq: []
# Course: INST631, Prereq: []
# Course: INST639N, Prereq: []
# Course: INST643, Prereq: []
# Course: INST650, Prereq: []
# Course: INST651, Prereq: []
# Course: INST653, Prereq: []
# Course: INST661, Prereq: []
# Course: INST680, Prereq: ['INFM600', 'LBSC602']
# Course: INST704, Prereq: ['INST631']
# Course: INST705, Prereq: []
# Course: INST709, Prereq: []
# Course: INST710, Prereq: []
# Course: INST711, Prereq: []
# Course: INST728D, Prereq: []
# Course: INST728F, Prereq: []
# Course: INST731, Prereq: ['INST661']
# Course: INST735, Prereq: ['CMSC422']
# Course: INST737, Prereq: ['INST627', 'LBSC690', 'LBSC671', 'INFM603', 'JOUR652']
# Course: INST752, Prereq: ['INFM600', 'INFM603', 'INST630', 'INST733']
# Course: INST753, Prereq: ['INFM600', 'INFM603', 'INST733']
# Course: INST754, Prereq: ['INFM600', 'INST630', 'INST733', 'INFM603', 'JOUR652']
# Course: INST760, Prereq: ['INST630', 'INFM603']
# Course: INST764, Prereq: []
# Course: INST771, Prereq: []
# Course: INST775, Prereq: ['INST631', 'INST632', 'INST717']
# Course: INST782, Prereq: ['INST604']
# Course: INST784, Prereq: ['INST604']
# Course: INST787, Prereq: ['AMST856', 'ANTH856', 'HIST810']
# Course: INST799, Prereq: []
# Course: INST800, Prereq: []
# Course: INST801, Prereq: []
# Course: INST818, Prereq: []
# Course: INST878D, Prereq: []
# Course: INST898, Prereq: []
# Course: INST899, Prereq: []
# Course: DATA110, Prereq: ['DATA100', 'STAT100', 'MATH135']
# Course: DATA120, Prereq: ['STAT100', 'MATH135']
# Course: DATA200, Prereq: ['STAT100', 'MATH135']
# Course: DATA250, Prereq: ['DATA110', 'DATA120', 'MATH141']
# Course: DATA350, Prereq: ['DATA100', 'STAT100', 'MATH135', 'DATA110', 'DATA120']
# Course: DATA400, Prereq: ['MATH131', 'MATH141']
# Course: DATA601, Prereq: []
# Course: DATA602, Prereq: []
# Course: DATA603, Prereq: []

# %%
df = pd.DataFrame(list(umd_courses.items()), columns=['Course', 'Prerequesites'])

df.to_csv("umd_course_prerequesites.csv", index=False)

df.head()
# Out:
#     Course                Prerequesites
# 0  AOSC123                           []
# 1  AOSC200  [MATH107, MATH110, MATH115]
# 2  AOSC201                           []
# 3  AOSC375                    [MATH120]
# 4  AOSC400  [PHYS171, PHYS161, MATH141]

# %%
expanded_data = []

for course,prereqs in umd_courses.items(): 
    for prereq in prereqs:
        expanded_data.append((course,prereq))
        
df_expanded = pd.DataFrame(expanded_data, columns=['Course', 'Prerequisite'])

df_expanded.to_csv('umd_course_prerequisites_expanded.csv', index=False)

# %%
g = nx.DiGraph()

for _, row in df_expanded.iterrows():
    course = row["Course"]
    
    prereq = row["Prerequisite"]
    
    if prereq != "None": 
        g.add_edge(prereq, course)

print(g.number_of_nodes())
print(g.number_of_edges())
# Out:
# 665
# 1407

# %%
# Centrality Measures
in_degree = nx.in_degree_centrality(g)
betweenness = nx.betweenness_centrality(g)
closeness = nx.closeness_centrality(g)

# Create DataFrame
centrality_df = pd.DataFrame({
    "Course": list(in_degree.keys()),
    "In-Degree Centrality (Importance)" : list(in_degree.values()),
    "Betweenness Centrality (Chokepoint)" : list(betweenness.values()),
    "Closeness Centrality (Efficiency)" : list(closeness.values())
})

# Sort the dataframe by chokepoint and importance Top 20
bottleneck_courses = centrality_df.sort_values(by=['Betweenness Centrality (Chokepoint)','In-Degree Centrality (Importance)'], ascending=False).head(20)

bottleneck_courses.to_csv("umd_stem_bottleneck_courses.csv", index=False)

bottleneck_courses
# Out:
#       Course  In-Degree Centrality (Importance)  \
# 55   MATH140                           0.001506
# 9    MATH141                           0.001506
# 3    MATH115                           0.004518
# 103  MATH246                           0.001506
# 4    MATH120                           0.004518
# 44   CHEM231                           0.010542
# 205  MATH340                           0.003012
# 149  CHEM241                           0.004518
# 151  CHEM242                           0.004518
# 564  STAT100                           0.007530
# 26   MATH241                           0.001506
# 189  MATH240                           0.003012
# 173  CMSC330                           0.003012
# 170  CMSC216                           0.003012
# 100  PHYS260                           0.003012
# 116  CHEM232                           0.009036
# 175  CMSC351                           0.003012
# 77   PHYS270                           0.004518
# 248  ENAE311                           0.015060
# 480  STAT410                           0.007530
#
#      Betweenness Centrality (Chokepoint)  Closeness Centrality (Efficiency)
# 55                              0.001890                           0.002711
# 9                               0.001518                           0.002677
# 3                               0.001509                           0.003012
# 103                             0.000414                           0.002689
# 4                               0.000347                           0.003389
# 44                              0.000346                           0.010327
# 205                             0.000335                           0.003765
# 149                             0.000321                           0.009413
# 151                             0.000302                           0.009413
# 564                             0.000297                           0.006275
# 26                              0.000295                           0.002689
# 189                             0.000277                           0.003614
# 173                             0.000275                           0.004880
# 170                             0.000268                           0.004341
# 100                             0.000265                           0.003614
# 116                             0.000247                           0.009111
# 175                             0.000226                           0.004880
# 77                              0.000217                           0.005083
# 248                             0.000211                           0.015446
# 480                             0.000210                           0.008283

# %%
from pyvis.network import Network

net = Network(notebook=True, directed=True, height='800px', width='100%', bgcolor='#222222', font_color='white')
net.toggle_physics(True)
for node in g.nodes:
    
    # conditions to color nodes that are in top 20 bottleneck courses
    if node in bottleneck_courses['Course'].values:
        net.add_node(node, label=node, title=f"BOTTLENECK: {node}", color = 'red', font={"size": 16})
    else:
        
        net.add_node(node, label=node, title=f"{node} (STEM Course)", color = 'blue',font={"size": 14})
        
    
for edge in g.edges:
    net.add_edge(edge[0], edge[1])
    

net.show("umd_prereq_network.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# umd_prereq_network.html
#         <iframe
#             width="100%"
#             height="800px"
#             src="umd_prereq_network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
