# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import networkx as nx 
import matplotlib.pyplot as plt
import re

# %%
# Global Variables
CATALOG_URL = 'https://app.testudo.umd.edu/soc/202501/' # Catalog for SPRING 2025 Classes
COURSE_PATTERN = re.compile(r"\b[A-Z]{4}\d{3}\b")

# %%
def get_prereq(department):
    
    url = f"{CATALOG_URL}{department}" # host url 
    
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    
    # Courses dictionary to turn into a pandas dataframe
    courses = {}
    
    # Extracts each div containing relevant metadata and takes the pattern from the prerequesites metadata as a course
    for course_div in soup.find_all("div", class_="course"):
        course_id = course_div.get("id")
        
        if not course_id: 
            continue
        
        # TODO: remove when done
        print(course_id)
        
        prereq_text = ""
        
        prereq_div = course_div.find("div", class_="approved-course-texts-container")
        if prereq_div: 
            prereq_section = prereq_div.find("strong", string="Prerequisite:")
            if prereq_section: 
                prereq_text = prereq_section.next_sibling.strip() if prereq_section.next_sibling else ""
                
        prerequisites = COURSE_PATTERN.findall(prereq_text)
        courses[course_id] = prerequisites
        
    
    return courses

# %%
# Example: Get prerequisites for STEM Departments UMD offers
departments = [
    "AOSC", "ANSC", "ASTR", "BCHM", "BIOE", "BIOL", "BIPH", "CBMG", "CHBE", "CHEM",
    "CMSC", "ENCE", "ENAE", "ENEE", "ENFP", "ENMA", "ENME", "ENSP", "ENST", "ENTM",
    "GEOG", "GEOL", "MATH", "NEUR", "PHYS", "PLSC", "STAT", "INST", "DATA"
]
umd_courses = {}

for dept in departments:
    umd_courses.update(get_prereq(dept))
# Out:
# AOSC123
# AOSC200
# AOSC201
# AOSC247
# AOSC360
# AOSC399
# AOSC401
# AOSC424
# AOSC432
# AOSC433
# AOSC447
# AOSC472
# AOSC494
# AOSC499
# AOSC602
# AOSC611
# AOSC615
# AOSC617
# AOSC621
# AOSC625
# AOSC633
# AOSC647
# AOSC650
# AOSC658Z
# AOSC798
# AOSC898
# AOSC899
# ANSC101
# ANSC103
# ANSC105
# ANSC115
# ANSC210
# ANSC212
# ANSC214
# ANSC227
# ANSC237
# ANSC245
# ANSC247
# ANSC250
# ANSC282
# ANSC315
# ANSC327
# ANSC330
# ANSC340
# ANSC359
# ANSC379
# ANSC388
# ANSC389
# ANSC399
# ANSC435
# ANSC440
# ANSC445
# ANSC452
# ANSC453
# ANSC624
# ANSC627
# ANSC630
# ANSC660
# ANSC688J
# ANSC688W
# ANSC699
# ANSC799
# ANSC898
# ANSC899
# ASTR100
# ASTR101
# ASTR121
# ASTR220
# ASTR230
# ASTR288
# ASTR288B
# ASTR288I
# ASTR288T
# ASTR300
# ASTR315
# ASTR320
# ASTR330
# ASTR340
# ASTR380
# ASTR399
# ASTR406
# ASTR435
# ASTR498
# ASTR615
# ASTR670
# ASTR688C
# ASTR699
# ASTR799
# ASTR898
# ASTR899
# BCHM461
# BCHM462
# BCHM463
# BCHM464
# BCHM465
# BCHM477
# BCHM485
# BCHM669C
# BCHM669D
# BCHM675
# BCHM676
# BCHM698
# BCHM699
# BCHM799
# BCHM889A
# BCHM889B
# BCHM889D
# BCHM889E
# BCHM889M
# BCHM898
# BCHM899
# BIOE120
# BIOE121
# BIOE221
# BIOE232
# BIOE241
# BIOE331
# BIOE340
# BIOE371
# BIOE372
# BIOE386
# BIOE389C
# BIOE389F
# BIOE389M
# BIOE399
# BIOE399H
# BIOE404
# BIOE413
# BIOE414
# BIOE437
# BIOE442
# BIOE447
# BIOE453
# BIOE461
# BIOE462
# BIOE464
# BIOE486
# BIOE488A
# BIOE489B
# BIOE489F
# BIOE489H
# BIOE489J
# BIOE489Q
# BIOE489R
# BIOE606
# BIOE608
# BIOE654
# BIOE658B
# BIOE658E
# BIOE689
# BIOE689A
# BIOE689C
# BIOE689N
# BIOE689W
# BIOE689X
# BIOE799
# BIOE898
# BIOE899
# BIOL609
# BIOL705
# BIOL706
# BIOL708C
# BIOL708D
# BIOL708R
# BIOL709V
# BIOL799
# BIOL898
# BIOL899
# BIPH697
# BIPH698L
# BIPH699
# BIPH703
# BIPH706
# BIPH799
# BIPH898
# BIPH899
# CBMG613
# CBMG688B
# CBMG688G
# CBMG688I
# CBMG688U
# CBMG699
# CBMG699C
# CBMG699D
# CBMG699W
# CBMG699X
# CBMG799
# CBMG898
# CBMG899
# CHBE101
# CHBE302
# CHBE333
# CHBE369
# CHBE422
# CHBE424
# CHBE426
# CHBE440
# CHBE446
# CHBE451
# CHBE457
# CHBE468
# CHBE469
# CHBE473
# CHBE480
# CHBE486
# CHBE497
# CHBE608
# CHBE609
# CHBE630
# CHBE640
# CHBE648
# CHBE651
# CHBE673
# CHBE680
# CHBE686
# CHBE697
# CHBE799
# CHBE898
# CHBE899
# CHEM131
# CHEM132
# CHEM134
# CHEM135
# CHEM136
# CHEM231
# CHEM232
# CHEM232S
# CHEM237
# CHEM241
# CHEM242
# CHEM271
# CHEM272
# CHEM276
# CHEM277
# CHEM298Q
# CHEM316
# CHEM395
# CHEM398
# CHEM399A
# CHEM399B
# CHEM399C
# CHEM399X
# CHEM401
# CHEM425
# CHEM433
# CHEM480
# CHEM481
# CHEM482
# CHEM483
# CHEM484
# CHEM498E
# CHEM608M
# CHEM625
# CHEM633
# CHEM647
# CHEM648P
# CHEM687
# CHEM699
# CHEM703
# CHEM705
# CHEM799
# CHEM889A
# CHEM889C
# CHEM889D
# CHEM889E
# CHEM889F
# CHEM889G
# CHEM889M
# CHEM898
# CHEM899
# CMSC115
# CMSC116
# CMSC122
# CMSC125
# CMSC131
# CMSC132
# CMSC216
# CMSC250
# CMSC298A
# CMSC298Q
# CMSC320
# CMSC330
# CMSC335
# CMSC351
# CMSC388J
# CMSC389E
# CMSC389O
# CMSC389P
# CMSC396H
# CMSC398L
# CMSC398M
# CMSC398N
# CMSC398R
# CMSC398W
# CMSC401
# CMSC411
# CMSC412
# CMSC414
# CMSC417
# CMSC420
# CMSC421
# CMSC422
# CMSC423
# CMSC424
# CMSC425
# CMSC426
# CMSC427
# CMSC430
# CMSC433
# CMSC434
# CMSC435
# CMSC436
# CMSC451
# CMSC452
# CMSC454
# CMSC456
# CMSC457
# CMSC460
# CMSC466
# CMSC470
# CMSC471
# CMSC475
# CMSC477
# CMSC498A
# CMSC498C
# CMSC498D
# CMSC498G
# CMSC498Y
# CMSC499A
# CMSC624
# CMSC656
# CMSC661
# CMSC701
# CMSC711
# CMSC714
# CMSC725
# CMSC734
# CMSC752
# CMSC764
# CMSC798
# CMSC799
# CMSC800
# CMSC818G
# CMSC818Q
# CMSC828C
# CMSC828F
# CMSC828G
# CMSC838E
# CMSC838M
# CMSC848G
# CMSC848M
# CMSC848O
# CMSC858P
# CMSC858Q
# CMSC898
# CMSC899
# ENCE100
# ENCE200
# ENCE201
# ENCE215
# ENCE300
# ENCE302
# ENCE305
# ENCE310
# ENCE320
# ENCE325
# ENCE340
# ENCE353
# ENCE360
# ENCE370
# ENCE402
# ENCE411
# ENCE412
# ENCE421
# ENCE422
# ENCE423
# ENCE424
# ENCE426
# ENCE431
# ENCE444
# ENCE455
# ENCE467
# ENCE472
# ENCE489
# ENCE489J
# ENCE489T
# ENCE604
# ENCE607
# ENCE614
# ENCE623
# ENCE627
# ENCE647
# ENCE661
# ENCE662
# ENCE673
# ENCE674
# ENCE677
# ENCE688E
# ENCE688F
# ENCE688M
# ENCE688O
# ENCE688W
# ENCE688Y
# ENCE689
# ENCE689T
# ENCE713
# ENCE741
# ENCE799
# ENCE898
# ENCE899
# ENAE200
# ENAE202
# ENAE311
# ENAE311H
# ENAE324
# ENAE398H
# ENAE404
# ENAE420
# ENAE425
# ENAE432
# ENAE450
# ENAE464
# ENAE467
# ENAE471
# ENAE482
# ENAE484
# ENAE488B
# ENAE488C
# ENAE488D
# ENAE488G
# ENAE488O
# ENAE488P
# ENAE488T
# ENAE499
# ENAE633
# ENAE634
# ENAE635
# ENAE646
# ENAE652
# ENAE654
# ENAE656
# ENAE665
# ENAE667
# ENAE674
# ENAE676
# ENAE682
# ENAE685
# ENAE697
# ENAE741
# ENAE788G
# ENAE788M
# ENAE788O
# ENAE788T
# ENAE788V
# ENAE788Z
# ENAE799
# ENAE898
# ENAE899
# ENEE101
# ENEE140
# ENEE150
# ENEE200
# ENEE205
# ENEE222
# ENEE244
# ENEE245
# ENEE290
# ENEE304
# ENEE305
# ENEE313
# ENEE322
# ENEE323
# ENEE324
# ENEE324H
# ENEE350
# ENEE351
# ENEE382
# ENEE396
# ENEE408A
# ENEE408D
# ENEE408I
# ENEE408J
# ENEE408M
# ENEE408N
# ENEE408W
# ENEE413
# ENEE419M
# ENEE425
# ENEE426
# ENEE428
# ENEE436
# ENEE439G
# ENEE440
# ENEE445
# ENEE446
# ENEE447
# ENEE456
# ENEE459C
# ENEE459V
# ENEE460
# ENEE461
# ENEE469O
# ENEE473
# ENEE475
# ENEE488
# ENEE491
# ENEE499
# ENEE499H
# ENEE601
# ENEE612
# ENEE621
# ENEE627
# ENEE633
# ENEE640
# ENEE645
# ENEE661
# ENEE664
# ENEE681
# ENEE692
# ENEE698P
# ENEE698Q
# ENEE699
# ENEE729F
# ENEE729Z
# ENEE739G
# ENEE769D
# ENEE790
# ENEE799
# ENEE898
# ENEE899
# ENFP101
# ENFP201
# ENFP310
# ENFP312
# ENFP350
# ENFP411
# ENFP413
# ENFP420
# ENFP426
# ENFP429
# ENFP461
# ENFP465
# ENFP489
# ENFP613
# ENFP619
# ENFP620
# ENFP629
# ENFP649
# ENFP655
# ENFP663
# ENFP665
# ENFP799
# ENMA165
# ENMA201
# ENMA300
# ENMA301
# ENMA417
# ENMA421
# ENMA460
# ENMA461
# ENMA465
# ENMA470
# ENMA475
# ENMA481
# ENMA486
# ENMA489E
# ENMA489M
# ENMA490
# ENMA499
# ENMA620
# ENMA621
# ENMA661
# ENMA671
# ENMA681
# ENMA685
# ENMA688
# ENMA698
# ENMA797
# ENMA799
# ENMA898
# ENMA899
# ENME201
# ENME202
# ENME208
# ENME272
# ENME299Z
# ENME331
# ENME332
# ENME350
# ENME351
# ENME361
# ENME371
# ENME382
# ENME392
# ENME400
# ENME401
# ENME408
# ENME413
# ENME416
# ENME420
# ENME427
# ENME431
# ENME433
# ENME435
# ENME436
# ENME437
# ENME440
# ENME461
# ENME462
# ENME464
# ENME472
# ENME488
# ENME489
# ENME489A
# ENME489D
# ENME489E
# ENME489P
# ENME489Q
# ENME489W
# ENME632
# ENME635
# ENME665
# ENME684
# ENME691
# ENME695
# ENME697
# ENME725
# ENME743
# ENME744
# ENME799
# ENME808
# ENME808C
# ENME808D
# ENME808J
# ENME808M
# ENME808P
# ENME808R
# ENME808V
# ENME898
# ENME899
# ENSP102
# ENSP330
# ENSP342
# ENSP370
# ENSP386
# ENSP399
# ENSP399R
# ENSP400
# ENSP499
# ENST200
# ENST214
# ENST233
# ENST309
# ENST334
# ENST388
# ENST389
# ENST405
# ENST421
# ENST422
# ENST423
# ENST430
# ENST436
# ENST452
# ENST453
# ENST462
# ENST470
# ENST472
# ENST481
# ENST486
# ENST487
# ENST489
# ENST499
# ENST499T
# ENST499V
# ENST499Y
# ENST622
# ENST630
# ENST681
# ENST689
# ENST689Q
# ENST689T
# ENST689Y
# ENST689Z
# ENST702
# ENST798
# ENST799
# ENST898
# ENST899
# ENTM699S
# ENTM725
# ENTM769
# ENTM788C
# ENTM798C
# ENTM798F
# ENTM799
# ENTM898
# ENTM899
# GEOG140
# GEOG156
# GEOG172
# GEOG201
# GEOG211
# GEOG212
# GEOG301
# GEOG306
# GEOG331
# GEOG333
# GEOG373
# GEOG384
# GEOG385
# GEOG398
# GEOG398E
# GEOG416
# GEOG422
# GEOG441
# GEOG470
# GEOG472
# GEOG473
# GEOG498
# GEOG606
# GEOG608
# GEOG646
# GEOG653
# GEOG661
# GEOG663
# GEOG670
# GEOG677
# GEOG683
# GEOG732
# GEOG770
# GEOG788
# GEOG788A
# GEOG788T
# GEOG789
# GEOG790
# GEOG797
# GEOG798
# GEOG799
# GEOG898
# GEOG899
# GEOL100
# GEOL102
# GEOL110
# GEOL120
# GEOL123
# GEOL204
# GEOL322
# GEOL340
# GEOL393
# GEOL394
# GEOL431
# GEOL435
# GEOL443
# GEOL447
# GEOL457
# GEOL488
# GEOL497
# GEOL497H
# GEOL499
# GEOL635
# GEOL647
# GEOL657
# GEOL680
# GEOL683
# GEOL688
# GEOL789J
# GEOL789R
# GEOL798
# GEOL799
# GEOL898
# GEOL899
# MATH003
# MATH007
# MATH013
# MATH015
# MATH107
# MATH113
# MATH115
# MATH120
# MATH121
# MATH135
# MATH136
# MATH140
# MATH141
# MATH141H
# MATH206
# MATH212
# MATH213
# MATH214
# MATH240
# MATH241
# MATH241H
# MATH243
# MATH246
# MATH246H
# MATH299G
# MATH299N
# MATH299R
# MATH310
# MATH314
# MATH341
# MATH386
# MATH401
# MATH402
# MATH403
# MATH404
# MATH405
# MATH406
# MATH410
# MATH411
# MATH416
# MATH420
# MATH423
# MATH424
# MATH430
# MATH437
# MATH446
# MATH452
# MATH456
# MATH461
# MATH462
# MATH463
# MATH464
# MATH470
# MATH475
# MATH489
# MATH498
# MATH498A
# MATH601
# MATH607
# MATH621
# MATH631
# MATH660
# MATH674
# MATH689
# MATH713
# MATH734
# MATH740
# MATH744
# MATH799
# MATH808A
# MATH818A
# MATH818T
# MATH838B
# MATH838R
# MATH848A
# MATH848G
# MATH848Z
# MATH858A
# MATH858M
# MATH858R
# MATH868A
# MATH868B
# MATH898
# MATH899
# NEUR200
# NEUR305
# NEUR306
# NEUR329
# NEUR379
# NEUR379H
# NEUR398H
# NEUR405
# NEUR479
# NEUR479H
# PHYS106
# PHYS107
# PHYS121
# PHYS122
# PHYS131
# PHYS132
# PHYS137
# PHYS161
# PHYS171
# PHYS171H
# PHYS172
# PHYS260
# PHYS261
# PHYS265
# PHYS270
# PHYS271
# PHYS272
# PHYS272H
# PHYS273
# PHYS273H
# PHYS275
# PHYS276
# PHYS282
# PHYS299
# PHYS299Q
# PHYS299W
# PHYS313
# PHYS332
# PHYS371
# PHYS375
# PHYS386
# PHYS389
# PHYS398
# PHYS399
# PHYS400
# PHYS401
# PHYS402
# PHYS404
# PHYS405
# PHYS406
# PHYS407
# PHYS410
# PHYS413
# PHYS420
# PHYS431
# PHYS441
# PHYS456
# PHYS457
# PHYS474
# PHYS487
# PHYS499A
# PHYS499B
# PHYS499V
# PHYS611
# PHYS613
# PHYS687
# PHYS703
# PHYS709
# PHYS721
# PHYS728J
# PHYS738
# PHYS739
# PHYS748
# PHYS749
# PHYS752
# PHYS758E
# PHYS759
# PHYS769
# PHYS778
# PHYS798
# PHYS798B
# PHYS798E
# PHYS798J
# PHYS798L
# PHYS798Q
# PHYS799
# PHYS830
# PHYS838C
# PHYS839A
# PHYS898
# PHYS899
# PLSC110
# PLSC111
# PLSC254
# PLSC271
# PLSC303
# PLSC388
# PLSC399
# PLSC400
# PLSC411
# PLSC434
# PLSC452
# PLSC460
# PLSC608T
# PLSC618
# PLSC619
# PLSC799
# PLSC898
# PLSC899
# STAT100
# STAT110
# STAT400
# STAT401
# STAT410
# STAT420
# STAT426
# STAT430
# STAT440
# STAT464
# STAT470
# STAT498A
# STAT601
# STAT650
# STAT689
# STAT701
# STAT741
# STAT799
# STAT808A
# STAT818A
# STAT818B
# STAT898
# STAT899
# INST104
# INST123
# INST126
# INST152
# INST154
# INST155
# INST156
# INST201
# INST204
# INST210
# INST227
# INST228
# INST309
# INST311
# INST314
# INST320
# INST326
# INST327
# INST335
# INST341
# INST346
# INST347
# INST352
# INST354
# INST362
# INST364
# INST366
# INST367
# INST371
# INST377
# INST380
# INST381
# INST388F
# INST388G
# INST388I
# INST388K
# INST388L
# INST388M
# INST388N
# INST388O
# INST388P
# INST398D
# INST398E
# INST406
# INST408I
# INST408Z
# INST410
# INST414
# INST443
# INST447
# INST450
# INST452
# INST454
# INST456
# INST462
# INST463
# INST464
# INST466
# INST467
# INST470
# INST490
# INST600
# INST604
# INST608B
# INST608S
# INST612
# INST614
# INST616
# INST622
# INST630
# INST639G
# INST639L
# INST641
# INST646
# INST652
# INST653
# INST682
# INST702
# INST703
# INST709
# INST710
# INST711
# INST725
# INST726
# INST728L
# INST728M
# INST728N
# INST728R
# INST728X
# INST730
# INST733
# INST737
# INST742
# INST750
# INST762
# INST767
# INST771
# INST776
# INST779
# INST785
# INST786
# INST787
# INST788C
# INST798
# INST799
# INST802
# INST808
# INST809
# INST818
# INST828
# INST878F
# INST878K
# INST878T
# INST878U
# INST898
# INST899
# DATA100
# DATA110
# DATA120
# DATA200
# DATA250
# DATA320
# DATA350
# DATA400
# DATA602
# DATA603
# DATA604
# DATA605
# DATA606
# DATA641

# %%
for key, value in umd_courses.items(): 
    print(f'Course: {key}, Prereq: {value} ')
    
    # ISSUE: each row has multiple cell values
# Out:
# Course: AOSC123, Prereq: []
# Course: AOSC200, Prereq: ['MATH107', 'MATH110', 'MATH115']
# Course: AOSC201, Prereq: []
# Course: AOSC247, Prereq: ['MATH140']
# Course: AOSC360, Prereq: ['MATH107', 'MATH113', 'MATH115']
# Course: AOSC399, Prereq: []
# Course: AOSC401, Prereq: ['AOSC400', 'AOSC200', 'MATH141', 'PHYS161', 'PHYS171']
# Course: AOSC424, Prereq: ['PHYS171', 'PHYS161', 'MATH141']
# Course: AOSC432, Prereq: ['AOSC431']
# Course: AOSC433, Prereq: ['CHEM131', 'CHEM135', 'CHEM146', 'MATH241']
# Course: AOSC447, Prereq: ['MATH140']
# Course: AOSC472, Prereq: ['AOSC432', 'AOSC600', 'AOSC610', 'AOSC470']
# Course: AOSC494, Prereq: ['AOSC431', 'AOSC432']
# Course: AOSC499, Prereq: []
# Course: AOSC602, Prereq: []
# Course: AOSC611, Prereq: []
# Course: AOSC615, Prereq: []
# Course: AOSC617, Prereq: ['AOSC610']
# Course: AOSC621, Prereq: ['MATH462']
# Course: AOSC625, Prereq: []
# Course: AOSC633, Prereq: ['CHEM131', 'CHEM135', 'CHEM146']
# Course: AOSC647, Prereq: ['MATH140']
# Course: AOSC650, Prereq: []
# Course: AOSC658Z, Prereq: []
# Course: AOSC798, Prereq: []
# Course: AOSC898, Prereq: []
# Course: AOSC899, Prereq: []
# Course: ANSC101, Prereq: []
# Course: ANSC103, Prereq: ['ANSC101']
# Course: ANSC105, Prereq: []
# Course: ANSC115, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC210, Prereq: ['ANSC204', 'ANSC205', 'ANSC201']
# Course: ANSC212, Prereq: ['ANSC211', 'ANSC204', 'ANSC205']
# Course: ANSC214, Prereq: ['ANSC212']
# Course: ANSC227, Prereq: []
# Course: ANSC237, Prereq: ['ANSC232']
# Course: ANSC245, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC247, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC250, Prereq: []
# Course: ANSC282, Prereq: ['ANSC101', 'ANSC103']
# Course: ANSC315, Prereq: ['ANSC314']
# Course: ANSC327, Prereq: ['ANSC101', 'CHEM131', 'ANSC103', 'BSCI105', 'BSCI170', 'BSCI171']
# Course: ANSC330, Prereq: ['ANSC232']
# Course: ANSC340, Prereq: ['BSCI223', 'ANSC220', 'ANSC232', 'ANSC242', 'ANSC250', 'ANSC255', 'ANSC260', 'ANSC262']
# Course: ANSC359, Prereq: []
# Course: ANSC379, Prereq: []
# Course: ANSC388, Prereq: []
# Course: ANSC389, Prereq: []
# Course: ANSC399, Prereq: []
# Course: ANSC435, Prereq: ['ANSC212', 'ANSC201']
# Course: ANSC440, Prereq: ['BSCI223', 'ANSC212', 'ANSC327', 'BSCI222', 'BSCI421', 'NFSC430']
# Course: ANSC445, Prereq: ['ANSC212']
# Course: ANSC452, Prereq: ['ANSC212']
# Course: ANSC453, Prereq: ['ANSC101', 'ANSC103', 'BSCI106', 'BSCI160', 'BSCI161']
# Course: ANSC624, Prereq: []
# Course: ANSC627, Prereq: []
# Course: ANSC630, Prereq: []
# Course: ANSC660, Prereq: []
# Course: ANSC688J, Prereq: []
# Course: ANSC688W, Prereq: []
# Course: ANSC699, Prereq: []
# Course: ANSC799, Prereq: []
# Course: ANSC898, Prereq: []
# Course: ANSC899, Prereq: []
# Course: ASTR100, Prereq: []
# Course: ASTR101, Prereq: []
# Course: ASTR121, Prereq: ['ASTR120', 'MATH140']
# Course: ASTR220, Prereq: []
# Course: ASTR230, Prereq: ['MATH115', 'MATH113']
# Course: ASTR288, Prereq: []
# Course: ASTR288B, Prereq: []
# Course: ASTR288I, Prereq: []
# Course: ASTR288T, Prereq: []
# Course: ASTR300, Prereq: ['ASTR100', 'ASTR101']
# Course: ASTR315, Prereq: []
# Course: ASTR320, Prereq: ['ASTR121', 'PHYS270', 'PHYS271', 'PHYS273']
# Course: ASTR330, Prereq: ['ASTR100', 'ASTR101']
# Course: ASTR340, Prereq: ['ASTR100', 'ASTR101']
# Course: ASTR380, Prereq: []
# Course: ASTR399, Prereq: []
# Course: ASTR406, Prereq: ['ASTR320']
# Course: ASTR435, Prereq: ['ASTR121', 'PHYS273', 'PHYS270', 'PHYS271']
# Course: ASTR498, Prereq: []
# Course: ASTR615, Prereq: []
# Course: ASTR670, Prereq: []
# Course: ASTR688C, Prereq: []
# Course: ASTR699, Prereq: []
# Course: ASTR799, Prereq: []
# Course: ASTR898, Prereq: []
# Course: ASTR899, Prereq: []
# Course: BCHM461, Prereq: ['CHEM271', 'CHEM272', 'CHEM276', 'CHEM277']
# Course: BCHM462, Prereq: ['BCHM461']
# Course: BCHM463, Prereq: ['CHEM271', 'CHEM272', 'CHEM276', 'CHEM277']
# Course: BCHM464, Prereq: ['BCHM461', 'BCHM463']
# Course: BCHM465, Prereq: ['BCHM461', 'BCHM463']
# Course: BCHM477, Prereq: ['CHEM271', 'CHEM276', 'CHEM277', 'CHEM272']
# Course: BCHM485, Prereq: ['CHEM481']
# Course: BCHM669C, Prereq: []
# Course: BCHM669D, Prereq: []
# Course: BCHM675, Prereq: ['CHEM481', 'BCHM461']
# Course: BCHM676, Prereq: ['BCHM461', 'BCHM463']
# Course: BCHM698, Prereq: []
# Course: BCHM699, Prereq: []
# Course: BCHM799, Prereq: []
# Course: BCHM889A, Prereq: []
# Course: BCHM889B, Prereq: []
# Course: BCHM889D, Prereq: []
# Course: BCHM889E, Prereq: []
# Course: BCHM889M, Prereq: []
# Course: BCHM898, Prereq: []
# Course: BCHM899, Prereq: []
# Course: BIOE120, Prereq: ['MATH140']
# Course: BIOE121, Prereq: ['BIOE120']
# Course: BIOE221, Prereq: ['BIOE120', 'BIOE121']
# Course: BIOE232, Prereq: ['PHYS261', 'PHYS260']
# Course: BIOE241, Prereq: []
# Course: BIOE331, Prereq: ['MATH246', 'BIOE120', 'BIOE121', 'BIOE241', 'BIOE371', 'BIOE232']
# Course: BIOE340, Prereq: ['BSCI330', 'BIOE331']
# Course: BIOE371, Prereq: ['BIOE241', 'MATH246']
# Course: BIOE372, Prereq: ['BIOE120', 'BIOE121', 'BIOE241']
# Course: BIOE386, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246']
# Course: BIOE389C, Prereq: []
# Course: BIOE389F, Prereq: []
# Course: BIOE389M, Prereq: []
# Course: BIOE399, Prereq: []
# Course: BIOE399H, Prereq: []
# Course: BIOE404, Prereq: ['MATH246', 'BIOE120', 'ENES102', 'BIOE121', 'BIOE241', 'BIOE371']
# Course: BIOE413, Prereq: ['BIOE241', 'BIOE120', 'BIOE121', 'MATH246', 'BIOE340']
# Course: BIOE414, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246', 'ENES102']
# Course: BIOE437, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246']
# Course: BIOE442, Prereq: ['BIOE241', 'BIOE120', 'BIOE121', 'MATH241']
# Course: BIOE447, Prereq: ['BIOE221']
# Course: BIOE453, Prereq: ['CHEM231', 'MATH246', 'CHEM232', 'BIOE120', 'BIOE121', 'BIOE241']
# Course: BIOE461, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246']
# Course: BIOE462, Prereq: ['BIOE120', 'BIOE121', 'BIOE241', 'MATH246', 'BSCI330', 'BIOE340']
# Course: BIOE464, Prereq: ['BIOE232', 'BIOE372', 'BIOE442', 'BIOE371', 'BIOE246']
# Course: BIOE486, Prereq: ['BIOE485']
# Course: BIOE488A, Prereq: []
# Course: BIOE489B, Prereq: []
# Course: BIOE489F, Prereq: []
# Course: BIOE489H, Prereq: []
# Course: BIOE489J, Prereq: []
# Course: BIOE489Q, Prereq: []
# Course: BIOE489R, Prereq: []
# Course: BIOE606, Prereq: []
# Course: BIOE608, Prereq: []
# Course: BIOE654, Prereq: []
# Course: BIOE658B, Prereq: []
# Course: BIOE658E, Prereq: []
# Course: BIOE689, Prereq: []
# Course: BIOE689A, Prereq: []
# Course: BIOE689C, Prereq: []
# Course: BIOE689N, Prereq: []
# Course: BIOE689W, Prereq: []
# Course: BIOE689X, Prereq: []
# Course: BIOE799, Prereq: []
# Course: BIOE898, Prereq: []
# Course: BIOE899, Prereq: []
# Course: BIOL609, Prereq: []
# Course: BIOL705, Prereq: []
# Course: BIOL706, Prereq: []
# Course: BIOL708C, Prereq: []
# Course: BIOL708D, Prereq: []
# Course: BIOL708R, Prereq: []
# Course: BIOL709V, Prereq: []
# Course: BIOL799, Prereq: []
# Course: BIOL898, Prereq: []
# Course: BIOL899, Prereq: []
# Course: BIPH697, Prereq: []
# Course: BIPH698L, Prereq: []
# Course: BIPH699, Prereq: []
# Course: BIPH703, Prereq: ['PHYS603', 'CHEM687']
# Course: BIPH706, Prereq: []
# Course: BIPH799, Prereq: []
# Course: BIPH898, Prereq: []
# Course: BIPH899, Prereq: []
# Course: CBMG613, Prereq: []
# Course: CBMG688B, Prereq: []
# Course: CBMG688G, Prereq: []
# Course: CBMG688I, Prereq: []
# Course: CBMG688U, Prereq: []
# Course: CBMG699, Prereq: []
# Course: CBMG699C, Prereq: []
# Course: CBMG699D, Prereq: []
# Course: CBMG699W, Prereq: []
# Course: CBMG699X, Prereq: []
# Course: CBMG799, Prereq: []
# Course: CBMG898, Prereq: []
# Course: CBMG899, Prereq: []
# Course: CHBE101, Prereq: ['CHEM135']
# Course: CHBE302, Prereq: ['CHBE301']
# Course: CHBE333, Prereq: []
# Course: CHBE369, Prereq: []
# Course: CHBE422, Prereq: ['CHBE101', 'CHBE250', 'MATH241', 'MATH246']
# Course: CHBE424, Prereq: ['CHBE422']
# Course: CHBE426, Prereq: []
# Course: CHBE440, Prereq: ['CHBE301', 'MATH241', 'MATH246']
# Course: CHBE446, Prereq: ['CHBE442', 'CHBE444']
# Course: CHBE451, Prereq: []
# Course: CHBE457, Prereq: ['MATH246', 'CHEM231', 'CHBE301', 'ENMA461', 'BIOE232']
# Course: CHBE468, Prereq: []
# Course: CHBE469, Prereq: []
# Course: CHBE473, Prereq: []
# Course: CHBE480, Prereq: ['BIOE120']
# Course: CHBE486, Prereq: ['CHBE302', 'CHBE424', 'CHBE440']
# Course: CHBE497, Prereq: ['BIOE120', 'CHBE302', 'CHBE440']
# Course: CHBE608, Prereq: []
# Course: CHBE609, Prereq: []
# Course: CHBE630, Prereq: ['CHBE422', 'ENCH424']
# Course: CHBE640, Prereq: ['CHBE440']
# Course: CHBE648, Prereq: []
# Course: CHBE651, Prereq: []
# Course: CHBE673, Prereq: []
# Course: CHBE680, Prereq: []
# Course: CHBE686, Prereq: ['CHBE302', 'CHBE424', 'CHBE440']
# Course: CHBE697, Prereq: []
# Course: CHBE799, Prereq: []
# Course: CHBE898, Prereq: []
# Course: CHBE899, Prereq: []
# Course: CHEM131, Prereq: ['MATH120']
# Course: CHEM132, Prereq: ['MATH120']
# Course: CHEM134, Prereq: ['CHEM131', 'CHEM146']
# Course: CHEM135, Prereq: ['MATH120']
# Course: CHEM136, Prereq: ['CHEM135', 'MATH120']
# Course: CHEM231, Prereq: ['CHEM131', 'CHEM135', 'CHEM146', 'CHEM132', 'CHEM136', 'CHEM147', 'CHEM177']
# Course: CHEM232, Prereq: ['CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM146', 'CHEM147']
# Course: CHEM232S, Prereq: ['CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM146', 'CHEM147']
# Course: CHEM237, Prereq: ['CHEM131', 'CHEM135', 'CHEM146', 'CHEM132', 'CHEM136', 'CHEM147']
# Course: CHEM241, Prereq: ['CHEM231', 'CHEM232', 'CHEM237']
# Course: CHEM242, Prereq: ['CHEM231', 'CHEM232', 'CHEM237']
# Course: CHEM271, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM272, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM276, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM277, Prereq: ['CHEM241', 'CHEM242', 'CHEM247']
# Course: CHEM298Q, Prereq: []
# Course: CHEM316, Prereq: ['CHEM241', 'CHEM242', 'CHEM247', 'CHEM271', 'CHEM276', 'CHEM272', 'CHEM277']
# Course: CHEM395, Prereq: []
# Course: CHEM398, Prereq: []
# Course: CHEM399A, Prereq: []
# Course: CHEM399B, Prereq: []
# Course: CHEM399C, Prereq: []
# Course: CHEM399X, Prereq: []
# Course: CHEM401, Prereq: ['CHEM276', 'CHEM271', 'CHEM247', 'CHEM241']
# Course: CHEM425, Prereq: ['CHEM272', 'CHEM271', 'CHEM276', 'CHEM277']
# Course: CHEM433, Prereq: ['CHEM131', 'CHEM135', 'CHEM146', 'MATH241']
# Course: CHEM480, Prereq: ['CHEM276', 'CHEM271', 'CHEM277', 'CHEM272', 'MATH140', 'MATH136', 'PHYS260', 'PHYS261', 'PHYS132']
# Course: CHEM481, Prereq: ['CHEM135', 'CHEM271', 'CHEM272', 'CHEM276', 'CHEM277', 'MATH141', 'PHYS260', 'PHYS261', 'PHYS141']
# Course: CHEM482, Prereq: ['CHEM135', 'CHEM271', 'CHEM272', 'CHEM276', 'CHEM277', 'MATH141', 'PHYS260', 'PHYS261', 'PHYS141']
# Course: CHEM483, Prereq: ['CHEM481']
# Course: CHEM484, Prereq: ['CHEM482']
# Course: CHEM498E, Prereq: []
# Course: CHEM608M, Prereq: []
# Course: CHEM625, Prereq: ['CHEM482']
# Course: CHEM633, Prereq: ['CHEM131', 'CHEM135', 'CHEM146']
# Course: CHEM647, Prereq: []
# Course: CHEM648P, Prereq: []
# Course: CHEM687, Prereq: ['CHEM684']
# Course: CHEM699, Prereq: []
# Course: CHEM703, Prereq: ['PHYS603', 'CHEM687']
# Course: CHEM705, Prereq: []
# Course: CHEM799, Prereq: []
# Course: CHEM889A, Prereq: []
# Course: CHEM889C, Prereq: []
# Course: CHEM889D, Prereq: []
# Course: CHEM889E, Prereq: []
# Course: CHEM889F, Prereq: []
# Course: CHEM889G, Prereq: []
# Course: CHEM889M, Prereq: []
# Course: CHEM898, Prereq: []
# Course: CHEM899, Prereq: []
# Course: CMSC115, Prereq: []
# Course: CMSC116, Prereq: []
# Course: CMSC122, Prereq: []
# Course: CMSC125, Prereq: ['MATH115']
# Course: CMSC131, Prereq: []
# Course: CMSC132, Prereq: ['CMSC131', 'MATH140']
# Course: CMSC216, Prereq: ['CMSC132', 'MATH141']
# Course: CMSC250, Prereq: ['CMSC131', 'MATH141']
# Course: CMSC298A, Prereq: []
# Course: CMSC298Q, Prereq: []
# Course: CMSC320, Prereq: ['CMSC216', 'CMSC250']
# Course: CMSC330, Prereq: ['CMSC250', 'CMSC216']
# Course: CMSC335, Prereq: ['CMSC216', 'CMSC250']
# Course: CMSC351, Prereq: ['CMSC250', 'CMSC216']
# Course: CMSC388J, Prereq: []
# Course: CMSC389E, Prereq: []
# Course: CMSC389O, Prereq: []
# Course: CMSC389P, Prereq: []
# Course: CMSC396H, Prereq: []
# Course: CMSC398L, Prereq: []
# Course: CMSC398M, Prereq: []
# Course: CMSC398N, Prereq: []
# Course: CMSC398R, Prereq: []
# Course: CMSC398W, Prereq: []
# Course: CMSC401, Prereq: ['GEOG276', 'CMSC330', 'CMSC351']
# Course: CMSC411, Prereq: ['CMSC330']
# Course: CMSC412, Prereq: ['CMSC330', 'CMSC351', 'CMSC414', 'CMSC417', 'CMSC420', 'CMSC430', 'CMSC433', 'CMSC435', 'ENEE440', 'ENEE457']
# Course: CMSC414, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC417, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC420, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC421, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC422, Prereq: ['CMSC320', 'CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC423, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC424, Prereq: ['CMSC351', 'CMSC330']
# Course: CMSC425, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC426, Prereq: ['CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC427, Prereq: ['CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC430, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC433, Prereq: ['CMSC330']
# Course: CMSC434, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC435, Prereq: ['CMSC412', 'CMSC417', 'CMSC420', 'CMSC430', 'CMSC433', 'ENEE447']
# Course: CMSC436, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC451, Prereq: ['CMSC351']
# Course: CMSC452, Prereq: ['CMSC351']
# Course: CMSC454, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC456, Prereq: ['CMSC106', 'CMSC131', 'ENEE150', 'CMSC330', 'CMSC351', 'ENEE324', 'ENEE380']
# Course: CMSC457, Prereq: ['MATH240', 'MATH341', 'MATH461', 'PHYS274', 'CMSC351', 'PHYS373']
# Course: CMSC460, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340', 'CMSC106', 'CMSC131', 'MATH246']
# Course: CMSC466, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340', 'CMSC106', 'CMSC131', 'MATH410']
# Course: CMSC470, Prereq: ['CMSC320', 'CMSC330', 'CMSC351', 'MATH240', 'MATH341', 'MATH461']
# Course: CMSC471, Prereq: ['CMSC330', 'CMSC351']
# Course: CMSC475, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340']
# Course: CMSC477, Prereq: ['MATH240', 'MATH341', 'MATH461', 'ENEE467', 'CMSC420']
# Course: CMSC498A, Prereq: []
# Course: CMSC498C, Prereq: []
# Course: CMSC498D, Prereq: []
# Course: CMSC498G, Prereq: []
# Course: CMSC498Y, Prereq: []
# Course: CMSC499A, Prereq: []
# Course: CMSC624, Prereq: ['CMSC424']
# Course: CMSC656, Prereq: ['CMSC451', 'CMSC452', 'CMSC456']
# Course: CMSC661, Prereq: ['MATH246', 'MATH462']
# Course: CMSC701, Prereq: []
# Course: CMSC711, Prereq: ['CMSC412']
# Course: CMSC714, Prereq: ['CMSC411', 'CMSC412']
# Course: CMSC725, Prereq: ['CMSC424', 'CMSC420']
# Course: CMSC734, Prereq: ['CMSC434']
# Course: CMSC752, Prereq: []
# Course: CMSC764, Prereq: ['MATH410']
# Course: CMSC798, Prereq: []
# Course: CMSC799, Prereq: []
# Course: CMSC800, Prereq: []
# Course: CMSC818G, Prereq: []
# Course: CMSC818Q, Prereq: []
# Course: CMSC828C, Prereq: []
# Course: CMSC828F, Prereq: []
# Course: CMSC828G, Prereq: []
# Course: CMSC838E, Prereq: []
# Course: CMSC838M, Prereq: []
# Course: CMSC848G, Prereq: []
# Course: CMSC848M, Prereq: []
# Course: CMSC848O, Prereq: []
# Course: CMSC858P, Prereq: []
# Course: CMSC858Q, Prereq: []
# Course: CMSC898, Prereq: []
# Course: CMSC899, Prereq: []
# Course: ENCE100, Prereq: []
# Course: ENCE200, Prereq: ['ENES100', 'MATH141', 'ENES102']
# Course: ENCE201, Prereq: ['ENES220', 'MATH241']
# Course: ENCE215, Prereq: ['CHEM135']
# Course: ENCE300, Prereq: ['ENES220']
# Course: ENCE302, Prereq: ['MATH246', 'ENCE201']
# Course: ENCE305, Prereq: ['ENES220', 'PHYS260', 'PHYS261']
# Course: ENCE310, Prereq: ['PHYS260', 'ENCE215']
# Course: ENCE320, Prereq: []
# Course: ENCE325, Prereq: []
# Course: ENCE340, Prereq: ['ENES220']
# Course: ENCE353, Prereq: ['MATH246', 'ENES220']
# Course: ENCE360, Prereq: ['ENCE201', 'MATH140']
# Course: ENCE370, Prereq: ['ENCE201', 'PHYS260', 'PHYS261']
# Course: ENCE402, Prereq: ['ENCE302']
# Course: ENCE411, Prereq: ['ENCE205', 'ENCE310']
# Course: ENCE412, Prereq: ['ENCE305', 'ENCE310']
# Course: ENCE421, Prereq: []
# Course: ENCE422, Prereq: []
# Course: ENCE423, Prereq: []
# Course: ENCE424, Prereq: []
# Course: ENCE426, Prereq: []
# Course: ENCE431, Prereq: ['ENCE305']
# Course: ENCE444, Prereq: ['ENCE353', 'ENCE340']
# Course: ENCE455, Prereq: ['ENCE353']
# Course: ENCE467, Prereq: ['ENCE465', 'ENCE302', 'ENCE305']
# Course: ENCE472, Prereq: ['ENCE302', 'ENCE370']
# Course: ENCE489, Prereq: []
# Course: ENCE489J, Prereq: []
# Course: ENCE489T, Prereq: []
# Course: ENCE604, Prereq: []
# Course: ENCE607, Prereq: []
# Course: ENCE614, Prereq: []
# Course: ENCE623, Prereq: ['ENCE423', 'ENCE662']
# Course: ENCE627, Prereq: []
# Course: ENCE647, Prereq: ['ENCE340']
# Course: ENCE661, Prereq: []
# Course: ENCE662, Prereq: []
# Course: ENCE673, Prereq: []
# Course: ENCE674, Prereq: []
# Course: ENCE677, Prereq: []
# Course: ENCE688E, Prereq: []
# Course: ENCE688F, Prereq: []
# Course: ENCE688M, Prereq: []
# Course: ENCE688O, Prereq: []
# Course: ENCE688W, Prereq: []
# Course: ENCE688Y, Prereq: []
# Course: ENCE689, Prereq: []
# Course: ENCE689T, Prereq: []
# Course: ENCE713, Prereq: []
# Course: ENCE741, Prereq: []
# Course: ENCE799, Prereq: []
# Course: ENCE898, Prereq: []
# Course: ENCE899, Prereq: []
# Course: ENAE200, Prereq: []
# Course: ENAE202, Prereq: []
# Course: ENAE311, Prereq: ['PHYS271', 'MATH240', 'MATH461', 'PHYS270', 'MATH246', 'ENAE283', 'ENES220', 'ENAE202', 'MATH241', 'ENES232']
# Course: ENAE311H, Prereq: ['PHYS271', 'MATH240', 'MATH461', 'PHYS270', 'MATH246', 'ENAE283', 'ENES220', 'ENAE202', 'MATH241', 'ENES232']
# Course: ENAE324, Prereq: ['ENES220']
# Course: ENAE398H, Prereq: []
# Course: ENAE404, Prereq: ['ENAE301']
# Course: ENAE420, Prereq: ['ENES220', 'MATH241']
# Course: ENAE425, Prereq: ['MATH246', 'ENAE324', 'ENES220', 'MATH241']
# Course: ENAE432, Prereq: ['ENAE301', 'ENAE283']
# Course: ENAE450, Prereq: ['ENME480', 'ENAE380']
# Course: ENAE464, Prereq: ['ENAE324', 'ENAE362', 'ENAE311', 'ENAE432']
# Course: ENAE467, Prereq: ['ENAE457']
# Course: ENAE471, Prereq: ['ENAE414']
# Course: ENAE482, Prereq: ['ENAE455', 'ENAE423', 'ENAE403', 'ENAE481']
# Course: ENAE484, Prereq: ['ENAE423', 'ENAE483', 'ENAE441', 'ENAE457']
# Course: ENAE488B, Prereq: []
# Course: ENAE488C, Prereq: []
# Course: ENAE488D, Prereq: []
# Course: ENAE488G, Prereq: []
# Course: ENAE488O, Prereq: []
# Course: ENAE488P, Prereq: []
# Course: ENAE488T, Prereq: []
# Course: ENAE499, Prereq: []
# Course: ENAE633, Prereq: ['ENAE631']
# Course: ENAE634, Prereq: ['ENAE631']
# Course: ENAE635, Prereq: ['ENAE631']
# Course: ENAE646, Prereq: ['ENAE301']
# Course: ENAE652, Prereq: []
# Course: ENAE654, Prereq: []
# Course: ENAE656, Prereq: ['ENAE655']
# Course: ENAE665, Prereq: ['ENAE455']
# Course: ENAE667, Prereq: ['ENAE457']
# Course: ENAE674, Prereq: []
# Course: ENAE676, Prereq: ['ENAE673']
# Course: ENAE682, Prereq: []
# Course: ENAE685, Prereq: ['ENAE684']
# Course: ENAE697, Prereq: []
# Course: ENAE741, Prereq: ['ENAE601', 'ENAE432']
# Course: ENAE788G, Prereq: []
# Course: ENAE788M, Prereq: []
# Course: ENAE788O, Prereq: []
# Course: ENAE788T, Prereq: []
# Course: ENAE788V, Prereq: []
# Course: ENAE788Z, Prereq: []
# Course: ENAE799, Prereq: []
# Course: ENAE898, Prereq: []
# Course: ENAE899, Prereq: []
# Course: ENEE101, Prereq: []
# Course: ENEE140, Prereq: []
# Course: ENEE150, Prereq: ['ENEE140', 'CMSC131']
# Course: ENEE200, Prereq: []
# Course: ENEE205, Prereq: ['PHYS260', 'PHYS261']
# Course: ENEE222, Prereq: ['ENEE140', 'CMSC131']
# Course: ENEE244, Prereq: ['CMSC132', 'ENEE150']
# Course: ENEE245, Prereq: ['ENEE244', 'ENEE150', 'CMSC132']
# Course: ENEE290, Prereq: ['MATH141']
# Course: ENEE304, Prereq: ['ENEE205']
# Course: ENEE305, Prereq: ['ENEE304']
# Course: ENEE313, Prereq: ['ENEE205']
# Course: ENEE322, Prereq: ['MATH246', 'ENEE290', 'ENEE222']
# Course: ENEE323, Prereq: ['MATH246', 'ENEE290', 'ENEE222']
# Course: ENEE324, Prereq: ['MATH246', 'ENEE222']
# Course: ENEE324H, Prereq: ['MATH246', 'ENEE222']
# Course: ENEE350, Prereq: ['ENEE244', 'ENEE150', 'CMSC132']
# Course: ENEE351, Prereq: ['ENEE150', 'ENEE244']
# Course: ENEE382, Prereq: ['ENEE205', 'MATH241', 'PHYS270', 'PHYS271']
# Course: ENEE396, Prereq: []
# Course: ENEE408A, Prereq: []
# Course: ENEE408D, Prereq: []
# Course: ENEE408I, Prereq: []
# Course: ENEE408J, Prereq: []
# Course: ENEE408M, Prereq: []
# Course: ENEE408N, Prereq: []
# Course: ENEE408W, Prereq: []
# Course: ENEE413, Prereq: ['ENEE313', 'ENEE304']
# Course: ENEE419M, Prereq: []
# Course: ENEE425, Prereq: ['ENEE322', 'ENEE323']
# Course: ENEE426, Prereq: ['ENEE324', 'STAT400']
# Course: ENEE428, Prereq: []
# Course: ENEE436, Prereq: ['ENEE324', 'STAT400', 'ENEE150', 'CMSC216']
# Course: ENEE439G, Prereq: []
# Course: ENEE440, Prereq: ['ENEE350']
# Course: ENEE445, Prereq: ['ENEE205', 'ENEE350']
# Course: ENEE446, Prereq: ['ENEE350']
# Course: ENEE447, Prereq: ['CMSC414', 'CMSC417', 'CMSC420', 'CMSC430', 'CMSC433', 'CMSC435', 'ENEE440', 'ENEE457', 'ENEE350', 'CMSC330', 'CMSC351']
# Course: ENEE456, Prereq: ['CMSC106', 'CMSC131', 'ENEE150', 'CMSC330', 'CMSC351', 'ENEE324', 'ENEE380']
# Course: ENEE459C, Prereq: []
# Course: ENEE459V, Prereq: []
# Course: ENEE460, Prereq: ['ENEE322', 'ENEE290', 'MATH240', 'MATH461']
# Course: ENEE461, Prereq: ['ENEE205', 'ENEE322', 'ENEE323']
# Course: ENEE469O, Prereq: []
# Course: ENEE473, Prereq: ['ENEE205']
# Course: ENEE475, Prereq: ['ENEE303', 'ENEE304']
# Course: ENEE488, Prereq: []
# Course: ENEE491, Prereq: ['PHYS270', 'ENEE205', 'ENEE290', 'MATH461']
# Course: ENEE499, Prereq: []
# Course: ENEE499H, Prereq: []
# Course: ENEE601, Prereq: []
# Course: ENEE612, Prereq: ['ENEE303', 'ENEE475', 'ENEE476']
# Course: ENEE621, Prereq: ['ENEE620']
# Course: ENEE627, Prereq: ['ENEE620']
# Course: ENEE633, Prereq: ['MATH461']
# Course: ENEE640, Prereq: ['ENEE303', 'ENEE350']
# Course: ENEE645, Prereq: ['ENEE350', 'CMSC216']
# Course: ENEE661, Prereq: ['ENEE660', 'MATH410', 'MATH411']
# Course: ENEE664, Prereq: ['ENEE660', 'MATH410']
# Course: ENEE681, Prereq: ['ENEE381']
# Course: ENEE692, Prereq: ['ENEE380', 'ENEE381']
# Course: ENEE698P, Prereq: []
# Course: ENEE698Q, Prereq: []
# Course: ENEE699, Prereq: []
# Course: ENEE729F, Prereq: []
# Course: ENEE729Z, Prereq: []
# Course: ENEE739G, Prereq: []
# Course: ENEE769D, Prereq: []
# Course: ENEE790, Prereq: []
# Course: ENEE799, Prereq: []
# Course: ENEE898, Prereq: []
# Course: ENEE899, Prereq: []
# Course: ENFP101, Prereq: []
# Course: ENFP201, Prereq: ['MATH141']
# Course: ENFP310, Prereq: ['ENFP300']
# Course: ENFP312, Prereq: ['ENES232', 'ENFP300']
# Course: ENFP350, Prereq: []
# Course: ENFP411, Prereq: []
# Course: ENFP413, Prereq: ['ENFP250']
# Course: ENFP420, Prereq: ['ENFP312']
# Course: ENFP426, Prereq: []
# Course: ENFP429, Prereq: []
# Course: ENFP461, Prereq: []
# Course: ENFP465, Prereq: []
# Course: ENFP489, Prereq: []
# Course: ENFP613, Prereq: []
# Course: ENFP619, Prereq: []
# Course: ENFP620, Prereq: []
# Course: ENFP629, Prereq: []
# Course: ENFP649, Prereq: []
# Course: ENFP655, Prereq: []
# Course: ENFP663, Prereq: []
# Course: ENFP665, Prereq: []
# Course: ENFP799, Prereq: []
# Course: ENMA165, Prereq: []
# Course: ENMA201, Prereq: []
# Course: ENMA300, Prereq: ['ENES100']
# Course: ENMA301, Prereq: ['ENMA180', 'ENMA300']
# Course: ENMA417, Prereq: []
# Course: ENMA421, Prereq: []
# Course: ENMA460, Prereq: ['PHYS271', 'PHYS270', 'MATH241']
# Course: ENMA461, Prereq: ['ENMA300']
# Course: ENMA465, Prereq: ['ENMA300']
# Course: ENMA470, Prereq: []
# Course: ENMA475, Prereq: ['MATH246', 'PHYS270', 'PHYS271']
# Course: ENMA481, Prereq: ['ENMA300']
# Course: ENMA486, Prereq: []
# Course: ENMA489E, Prereq: []
# Course: ENMA489M, Prereq: []
# Course: ENMA490, Prereq: ['ENMA487']
# Course: ENMA499, Prereq: []
# Course: ENMA620, Prereq: ['ENMA471']
# Course: ENMA621, Prereq: []
# Course: ENMA661, Prereq: ['ENMA660']
# Course: ENMA671, Prereq: []
# Course: ENMA681, Prereq: []
# Course: ENMA685, Prereq: []
# Course: ENMA688, Prereq: []
# Course: ENMA698, Prereq: []
# Course: ENMA797, Prereq: []
# Course: ENMA799, Prereq: []
# Course: ENMA898, Prereq: []
# Course: ENMA899, Prereq: []
# Course: ENME201, Prereq: []
# Course: ENME202, Prereq: []
# Course: ENME208, Prereq: []
# Course: ENME272, Prereq: ['MATH141']
# Course: ENME299Z, Prereq: []
# Course: ENME331, Prereq: ['ENES232', 'ENES221']
# Course: ENME332, Prereq: ['ENME331']
# Course: ENME350, Prereq: ['PHYS271', 'PHYS270']
# Course: ENME351, Prereq: ['PHYS271', 'ENME350', 'PHYS270']
# Course: ENME361, Prereq: ['ENES220', 'ENES221', 'MATH246', 'MATH206', 'ENME202']
# Course: ENME371, Prereq: ['ENES221', 'ENME392', 'STAT400']
# Course: ENME382, Prereq: ['ENES100']
# Course: ENME392, Prereq: ['MATH241']
# Course: ENME400, Prereq: ['ENME361']
# Course: ENME401, Prereq: []
# Course: ENME408, Prereq: []
# Course: ENME413, Prereq: ['ENME351']
# Course: ENME416, Prereq: ['ENME331', 'ENME272', 'ENME414']
# Course: ENME420, Prereq: ['ENES232']
# Course: ENME427, Prereq: ['ENES220', 'ENME382']
# Course: ENME431, Prereq: ['MATH246']
# Course: ENME433, Prereq: []
# Course: ENME435, Prereq: ['ENME351']
# Course: ENME436, Prereq: ['ENME331']
# Course: ENME437, Prereq: ['ENME202', 'ENME392']
# Course: ENME440, Prereq: ['ENME392']
# Course: ENME461, Prereq: ['ENME351', 'ENME361']
# Course: ENME462, Prereq: ['ENME361']
# Course: ENME464, Prereq: ['ENME392']
# Course: ENME472, Prereq: ['ENME331', 'ENME361', 'ENME351', 'ENME371', 'ENME332']
# Course: ENME488, Prereq: []
# Course: ENME489, Prereq: []
# Course: ENME489A, Prereq: []
# Course: ENME489D, Prereq: []
# Course: ENME489E, Prereq: []
# Course: ENME489P, Prereq: []
# Course: ENME489Q, Prereq: []
# Course: ENME489W, Prereq: []
# Course: ENME632, Prereq: []
# Course: ENME635, Prereq: []
# Course: ENME665, Prereq: ['ENME662']
# Course: ENME684, Prereq: ['ENME670']
# Course: ENME691, Prereq: ['ENME202']
# Course: ENME695, Prereq: []
# Course: ENME697, Prereq: ['ENME202', 'ENME392']
# Course: ENME725, Prereq: []
# Course: ENME743, Prereq: ['ENME392']
# Course: ENME744, Prereq: ['ENME272', 'ENME331', 'ENME416']
# Course: ENME799, Prereq: []
# Course: ENME808, Prereq: []
# Course: ENME808C, Prereq: []
# Course: ENME808D, Prereq: []
# Course: ENME808J, Prereq: []
# Course: ENME808M, Prereq: []
# Course: ENME808P, Prereq: []
# Course: ENME808R, Prereq: []
# Course: ENME808V, Prereq: []
# Course: ENME898, Prereq: []
# Course: ENME899, Prereq: []
# Course: ENSP102, Prereq: []
# Course: ENSP330, Prereq: []
# Course: ENSP342, Prereq: []
# Course: ENSP370, Prereq: []
# Course: ENSP386, Prereq: []
# Course: ENSP399, Prereq: []
# Course: ENSP399R, Prereq: []
# Course: ENSP400, Prereq: ['ENSP101', 'ENSP102']
# Course: ENSP499, Prereq: []
# Course: ENST200, Prereq: []
# Course: ENST214, Prereq: ['BSCI160', 'BSCI161']
# Course: ENST233, Prereq: []
# Course: ENST309, Prereq: []
# Course: ENST334, Prereq: ['CHEM131', 'CHEM132', 'BSCI207']
# Course: ENST388, Prereq: []
# Course: ENST389, Prereq: []
# Course: ENST405, Prereq: ['MATH140', 'MATH120', 'MATH220']
# Course: ENST421, Prereq: ['ENST200']
# Course: ENST422, Prereq: ['ENST200']
# Course: ENST423, Prereq: ['ENST200']
# Course: ENST430, Prereq: ['ENST200']
# Course: ENST436, Prereq: ['ENST233']
# Course: ENST452, Prereq: ['BSCI160', 'BSCI161', 'BSCI106', 'BSCI362', 'ENST450', 'ENST360', 'BSCI361']
# Course: ENST453, Prereq: ['MATH120', 'ENST200', 'GEOG306', 'BIOM301']
# Course: ENST462, Prereq: ['ENST460', 'BSCI160', 'BSCI161', 'BSCI106', 'BSCI170', 'BSCI171', 'BSCI105']
# Course: ENST470, Prereq: []
# Course: ENST472, Prereq: []
# Course: ENST481, Prereq: ['MATH120', 'MATH140', 'MATH220', 'PHYS121', 'CHEM131', 'BSCI361']
# Course: ENST486, Prereq: ['ENST389']
# Course: ENST487, Prereq: []
# Course: ENST489, Prereq: []
# Course: ENST499, Prereq: []
# Course: ENST499T, Prereq: []
# Course: ENST499V, Prereq: []
# Course: ENST499Y, Prereq: []
# Course: ENST622, Prereq: ['ENST200']
# Course: ENST630, Prereq: ['ENST200']
# Course: ENST681, Prereq: ['CHEM131', 'PHYS121']
# Course: ENST689, Prereq: []
# Course: ENST689Q, Prereq: []
# Course: ENST689T, Prereq: []
# Course: ENST689Y, Prereq: []
# Course: ENST689Z, Prereq: []
# Course: ENST702, Prereq: ['ENST602']
# Course: ENST798, Prereq: []
# Course: ENST799, Prereq: []
# Course: ENST898, Prereq: []
# Course: ENST899, Prereq: []
# Course: ENTM699S, Prereq: []
# Course: ENTM725, Prereq: []
# Course: ENTM769, Prereq: []
# Course: ENTM788C, Prereq: []
# Course: ENTM798C, Prereq: []
# Course: ENTM798F, Prereq: []
# Course: ENTM799, Prereq: []
# Course: ENTM898, Prereq: []
# Course: ENTM899, Prereq: []
# Course: GEOG140, Prereq: []
# Course: GEOG156, Prereq: []
# Course: GEOG172, Prereq: []
# Course: GEOG201, Prereq: []
# Course: GEOG211, Prereq: ['GEOL120', 'GEOL100', 'GEOG201']
# Course: GEOG212, Prereq: []
# Course: GEOG301, Prereq: ['GEOG201', 'GEOG211']
# Course: GEOG306, Prereq: []
# Course: GEOG331, Prereq: ['ANTH220', 'ANTH260', 'GEOG202', 'GEOG201']
# Course: GEOG333, Prereq: ['GEOG201', 'GEOG202']
# Course: GEOG373, Prereq: []
# Course: GEOG384, Prereq: ['GEOG211', 'GEOG306', 'GEOG212', 'GEOG201', 'ENGL393', 'ENGL390']
# Course: GEOG385, Prereq: ['GEOG211', 'GEOG306', 'GEOG212', 'GEOG201']
# Course: GEOG398, Prereq: []
# Course: GEOG398E, Prereq: []
# Course: GEOG416, Prereq: []
# Course: GEOG422, Prereq: ['GEOG201', 'GEOG202', 'GEOG335', 'GEOG333']
# Course: GEOG441, Prereq: ['GEOG140']
# Course: GEOG470, Prereq: ['GEOG276', 'CMSC330', 'CMSC351']
# Course: GEOG472, Prereq: ['GEOG272', 'GEOG306']
# Course: GEOG473, Prereq: ['GEOG306', 'GEOG373']
# Course: GEOG498, Prereq: []
# Course: GEOG606, Prereq: ['GEOG305']
# Course: GEOG608, Prereq: []
# Course: GEOG646, Prereq: []
# Course: GEOG653, Prereq: ['GEOG579']
# Course: GEOG661, Prereq: []
# Course: GEOG663, Prereq: []
# Course: GEOG670, Prereq: []
# Course: GEOG677, Prereq: []
# Course: GEOG683, Prereq: []
# Course: GEOG732, Prereq: []
# Course: GEOG770, Prereq: ['GEOG276']
# Course: GEOG788, Prereq: []
# Course: GEOG788A, Prereq: []
# Course: GEOG788T, Prereq: []
# Course: GEOG789, Prereq: []
# Course: GEOG790, Prereq: []
# Course: GEOG797, Prereq: []
# Course: GEOG798, Prereq: []
# Course: GEOG799, Prereq: []
# Course: GEOG898, Prereq: []
# Course: GEOG899, Prereq: []
# Course: GEOL100, Prereq: []
# Course: GEOL102, Prereq: ['GEOL120', 'GEOL100', 'GEOL110']
# Course: GEOL110, Prereq: ['GEOL120', 'GEOL100']
# Course: GEOL120, Prereq: []
# Course: GEOL123, Prereq: []
# Course: GEOL204, Prereq: []
# Course: GEOL322, Prereq: ['GEOL120', 'GEOL100', 'GEOL110', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM103']
# Course: GEOL340, Prereq: ['GEOL120', 'GEOL100']
# Course: GEOL393, Prereq: ['PHYS141', 'PHYS161', 'PHYS174', 'MATH141', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL394, Prereq: ['GEOL393']
# Course: GEOL431, Prereq: ['BSCI207', 'BSCI392', 'GEOL104', 'GEOL204', 'GEOL331']
# Course: GEOL435, Prereq: ['MATH115', 'GEOL100', 'GEOL120', 'GEOL436', 'GEOL444', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL443, Prereq: ['GEOL322', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136', 'CHEM103', 'GEOL423', 'GEOL100', 'GEOL120', 'GEOL110']
# Course: GEOL447, Prereq: ['MATH140', 'MATH141', 'PHYS141', 'PHYS161', 'PHYS171']
# Course: GEOL457, Prereq: ['GEOL120', 'GEOL100', 'MATH141', 'GEOL110', 'MATH140']
# Course: GEOL488, Prereq: []
# Course: GEOL497, Prereq: []
# Course: GEOL497H, Prereq: []
# Course: GEOL499, Prereq: []
# Course: GEOL635, Prereq: ['MATH115', 'GEOL100', 'GEOL120', 'GEOL436', 'GEOL444', 'CHEM131', 'CHEM132', 'CHEM135', 'CHEM136']
# Course: GEOL647, Prereq: ['MATH140', 'MATH141', 'PHYS141', 'PHYS161', 'PHYS171']
# Course: GEOL657, Prereq: ['MATH140', 'MATH141', 'PHYS141', 'PHYS161', 'PHYS171']
# Course: GEOL680, Prereq: ['MATH241', 'MATH462', 'GEOL446']
# Course: GEOL683, Prereq: []
# Course: GEOL688, Prereq: []
# Course: GEOL789J, Prereq: []
# Course: GEOL789R, Prereq: []
# Course: GEOL798, Prereq: []
# Course: GEOL799, Prereq: []
# Course: GEOL898, Prereq: []
# Course: GEOL899, Prereq: []
# Course: MATH003, Prereq: []
# Course: MATH007, Prereq: []
# Course: MATH013, Prereq: []
# Course: MATH015, Prereq: []
# Course: MATH107, Prereq: ['MATH107', 'MATH003']
# Course: MATH113, Prereq: ['MATH113']
# Course: MATH115, Prereq: ['MATH115', 'MATH003', 'MATH113']
# Course: MATH120, Prereq: ['MATH113', 'MATH115', 'MATH120']
# Course: MATH121, Prereq: ['MATH120', 'MATH130', 'MATH136', 'MATH140']
# Course: MATH135, Prereq: ['MATH113', 'MATH115', 'MATH120']
# Course: MATH136, Prereq: ['MATH135']
# Course: MATH140, Prereq: ['MATH115']
# Course: MATH141, Prereq: ['MATH140']
# Course: MATH141H, Prereq: ['MATH140']
# Course: MATH206, Prereq: ['MATH136', 'MATH140']
# Course: MATH212, Prereq: []
# Course: MATH213, Prereq: ['MATH212']
# Course: MATH214, Prereq: ['MATH212']
# Course: MATH240, Prereq: ['MATH131', 'MATH141']
# Course: MATH241, Prereq: ['MATH141']
# Course: MATH241H, Prereq: ['MATH141']
# Course: MATH243, Prereq: ['MATH141']
# Course: MATH246, Prereq: ['MATH141']
# Course: MATH246H, Prereq: ['MATH141']
# Course: MATH299G, Prereq: []
# Course: MATH299N, Prereq: []
# Course: MATH299R, Prereq: []
# Course: MATH310, Prereq: ['MATH141', 'MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340']
# Course: MATH314, Prereq: ['MATH214']
# Course: MATH341, Prereq: ['MATH340']
# Course: MATH386, Prereq: []
# Course: MATH401, Prereq: ['MATH461', 'MATH240', 'MATH341']
# Course: MATH402, Prereq: ['MATH240', 'MATH341', 'MATH461']
# Course: MATH403, Prereq: ['MATH240', 'MATH461', 'MATH340', 'MATH341', 'MATH241', 'MATH310']
# Course: MATH404, Prereq: ['MATH403']
# Course: MATH405, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH310']
# Course: MATH406, Prereq: ['MATH240', 'MATH241', 'MATH246', 'MATH340', 'MATH341', 'MATH461']
# Course: MATH410, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH340', 'MATH241', 'MATH310']
# Course: MATH411, Prereq: ['MATH410']
# Course: MATH416, Prereq: ['MATH141', 'MATH240', 'MATH461', 'MATH341']
# Course: MATH420, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH241', 'MATH340', 'MATH246', 'MATH341', 'STAT400', 'STAT410', 'CMSC106', 'CMSC131']
# Course: MATH423, Prereq: ['MATH240', 'MATH401', 'MATH461', 'MATH341']
# Course: MATH424, Prereq: ['MATH141', 'STAT400', 'STAT410']
# Course: MATH430, Prereq: ['MATH240', 'MATH341', 'MATH461']
# Course: MATH437, Prereq: ['MATH241', 'MATH340', 'MATH240', 'MATH341', 'MATH461']
# Course: MATH446, Prereq: ['MATH403', 'MATH410']
# Course: MATH452, Prereq: ['MATH341', 'MATH246', 'MATH240', 'MATH461']
# Course: MATH456, Prereq: ['CMSC106', 'CMSC131', 'ENEE150', 'CMSC330', 'CMSC351', 'ENEE324', 'ENEE380']
# Course: MATH461, Prereq: ['MATH141', 'MATH141']
# Course: MATH462, Prereq: ['MATH241', 'MATH340', 'MATH246', 'MATH341']
# Course: MATH463, Prereq: ['MATH241', 'MATH340']
# Course: MATH464, Prereq: ['MATH246', 'MATH341']
# Course: MATH470, Prereq: ['MATH141', 'MATH140', 'MATH461']
# Course: MATH475, Prereq: ['MATH240', 'MATH341', 'MATH461', 'MATH241', 'MATH340']
# Course: MATH489, Prereq: []
# Course: MATH498, Prereq: []
# Course: MATH498A, Prereq: []
# Course: MATH601, Prereq: ['MATH600']
# Course: MATH607, Prereq: ['MATH606']
# Course: MATH621, Prereq: ['MATH600', 'MATH620']
# Course: MATH631, Prereq: ['MATH630']
# Course: MATH660, Prereq: ['MATH410', 'MATH463']
# Course: MATH674, Prereq: ['MATH673', 'AMSC673']
# Course: MATH689, Prereq: []
# Course: MATH713, Prereq: ['MATH712']
# Course: MATH734, Prereq: ['MATH600', 'MATH432', 'MATH730']
# Course: MATH740, Prereq: ['MATH405', 'MATH411', 'MATH730']
# Course: MATH744, Prereq: ['MATH405', 'MATH403', 'MATH411', 'MATH432']
# Course: MATH799, Prereq: []
# Course: MATH808A, Prereq: []
# Course: MATH818A, Prereq: []
# Course: MATH818T, Prereq: []
# Course: MATH838B, Prereq: []
# Course: MATH838R, Prereq: []
# Course: MATH848A, Prereq: []
# Course: MATH848G, Prereq: []
# Course: MATH848Z, Prereq: []
# Course: MATH858A, Prereq: []
# Course: MATH858M, Prereq: []
# Course: MATH858R, Prereq: []
# Course: MATH868A, Prereq: []
# Course: MATH868B, Prereq: []
# Course: MATH898, Prereq: []
# Course: MATH899, Prereq: []
# Course: NEUR200, Prereq: ['BSCI170', 'BSCI171']
# Course: NEUR305, Prereq: ['MATH120', 'NEUR200', 'BSCI353']
# Course: NEUR306, Prereq: ['NEUR200', 'BSCI207', 'BSCI330']
# Course: NEUR329, Prereq: []
# Course: NEUR379, Prereq: []
# Course: NEUR379H, Prereq: []
# Course: NEUR398H, Prereq: []
# Course: NEUR405, Prereq: ['NEUR306', 'BSCI353', 'PHYS132']
# Course: NEUR479, Prereq: []
# Course: NEUR479H, Prereq: []
# Course: PHYS106, Prereq: []
# Course: PHYS107, Prereq: []
# Course: PHYS121, Prereq: ['MATH113', 'MATH115']
# Course: PHYS122, Prereq: ['PHYS121']
# Course: PHYS131, Prereq: ['CHEM131', 'MATH136', 'MATH140', 'BSCI160', 'BSCI161', 'BSCI106', 'BSCI170', 'BSCI171', 'BSCI105']
# Course: PHYS132, Prereq: ['PHYS131']
# Course: PHYS137, Prereq: []
# Course: PHYS161, Prereq: ['MATH141']
# Course: PHYS171, Prereq: ['MATH140']
# Course: PHYS171H, Prereq: ['MATH140']
# Course: PHYS172, Prereq: []
# Course: PHYS260, Prereq: ['PHYS161', 'MATH141']
# Course: PHYS261, Prereq: ['PHYS161']
# Course: PHYS265, Prereq: ['PHYS171', 'PHYS141', 'PHYS161']
# Course: PHYS270, Prereq: ['PHYS261', 'MATH241', 'PHYS260']
# Course: PHYS271, Prereq: ['PHYS261']
# Course: PHYS272, Prereq: ['PHYS161', 'PHYS171', 'MATH141', 'MATH241']
# Course: PHYS272H, Prereq: ['PHYS161', 'PHYS171', 'MATH141', 'MATH241']
# Course: PHYS273, Prereq: ['MATH241', 'PHYS272', 'PHYS274', 'MATH243', 'MATH246']
# Course: PHYS273H, Prereq: ['MATH241', 'PHYS272', 'PHYS274', 'MATH243', 'MATH246']
# Course: PHYS275, Prereq: ['PHYS171', 'PHYS161']
# Course: PHYS276, Prereq: ['PHYS272', 'PHYS275']
# Course: PHYS282, Prereq: []
# Course: PHYS299, Prereq: []
# Course: PHYS299Q, Prereq: []
# Course: PHYS299W, Prereq: []
# Course: PHYS313, Prereq: ['MATH241', 'PHYS273', 'PHYS274', 'MATH240', 'MATH243', 'MATH246']
# Course: PHYS332, Prereq: ['PHYS331', 'PHYS131']
# Course: PHYS371, Prereq: ['PHYS273', 'PHYS274', 'MATH243', 'MATH246']
# Course: PHYS375, Prereq: ['PHYS276', 'PHYS273']
# Course: PHYS386, Prereq: []
# Course: PHYS389, Prereq: []
# Course: PHYS398, Prereq: []
# Course: PHYS399, Prereq: []
# Course: PHYS400, Prereq: ['PHYS272', 'PHYS273', 'MATH241', 'MATH243', 'MATH246']
# Course: PHYS401, Prereq: ['PHYS371', 'PHYS313', 'PHYS373']
# Course: PHYS402, Prereq: ['PHYS401']
# Course: PHYS404, Prereq: ['PHYS371', 'PHYS420']
# Course: PHYS405, Prereq: ['PHYS375']
# Course: PHYS406, Prereq: ['PHYS375']
# Course: PHYS407, Prereq: ['PHYS499', 'PHYS375']
# Course: PHYS410, Prereq: ['PHYS265', 'PHYS273', 'MATH243', 'MATH246']
# Course: PHYS413, Prereq: ['PHYS313', 'PHYS412']
# Course: PHYS420, Prereq: ['MATH246', 'PHYS271', 'PHYS270', 'PHYS273']
# Course: PHYS431, Prereq: ['PHYS271', 'PHYS270', 'MATH241']
# Course: PHYS441, Prereq: ['PHYS401', 'PHYS402']
# Course: PHYS456, Prereq: ['PHYS276']
# Course: PHYS457, Prereq: ['MATH240', 'PHYS274', 'CMSC351', 'PHYS373']
# Course: PHYS474, Prereq: ['PHYS373', 'PHYS165', 'CMSC106', 'CMSC131']
# Course: PHYS487, Prereq: ['PHYS276']
# Course: PHYS499A, Prereq: []
# Course: PHYS499B, Prereq: []
# Course: PHYS499V, Prereq: []
# Course: PHYS611, Prereq: ['PHYS610']
# Course: PHYS613, Prereq: ['PHYS612']
# Course: PHYS687, Prereq: []
# Course: PHYS703, Prereq: ['PHYS603', 'CHEM687']
# Course: PHYS709, Prereq: []
# Course: PHYS721, Prereq: ['PHYS623']
# Course: PHYS728J, Prereq: []
# Course: PHYS738, Prereq: []
# Course: PHYS739, Prereq: []
# Course: PHYS748, Prereq: []
# Course: PHYS749, Prereq: []
# Course: PHYS752, Prereq: ['PHYS751', 'PHYS624']
# Course: PHYS758E, Prereq: []
# Course: PHYS759, Prereq: []
# Course: PHYS769, Prereq: []
# Course: PHYS778, Prereq: []
# Course: PHYS798, Prereq: []
# Course: PHYS798B, Prereq: []
# Course: PHYS798E, Prereq: []
# Course: PHYS798J, Prereq: []
# Course: PHYS798L, Prereq: []
# Course: PHYS798Q, Prereq: []
# Course: PHYS799, Prereq: []
# Course: PHYS830, Prereq: []
# Course: PHYS838C, Prereq: []
# Course: PHYS839A, Prereq: []
# Course: PHYS898, Prereq: []
# Course: PHYS899, Prereq: []
# Course: PLSC110, Prereq: []
# Course: PLSC111, Prereq: []
# Course: PLSC254, Prereq: ['PLSC110', 'PLSC111', 'PLSC253']
# Course: PLSC271, Prereq: ['PLSC110', 'PLSC111', 'BSCI170', 'BSCI171']
# Course: PLSC303, Prereq: ['BSCI170', 'BSCI171']
# Course: PLSC388, Prereq: []
# Course: PLSC399, Prereq: []
# Course: PLSC400, Prereq: ['BSCI170', 'BSCI171', 'PLSC201', 'CHEM231', 'CHEM232', 'CHEM237']
# Course: PLSC411, Prereq: ['BSCI170', 'BSCI171']
# Course: PLSC434, Prereq: []
# Course: PLSC452, Prereq: ['PLSC110', 'PLSC111', 'PLSC112', 'PLSC113', 'PLSC253', 'PLSC254']
# Course: PLSC460, Prereq: ['PLSC110', 'PLSC111', 'PLSC112', 'PLSC113', 'PLSC201']
# Course: PLSC608T, Prereq: []
# Course: PLSC618, Prereq: []
# Course: PLSC619, Prereq: []
# Course: PLSC799, Prereq: []
# Course: PLSC898, Prereq: []
# Course: PLSC899, Prereq: []
# Course: STAT100, Prereq: ['MATH110', 'MATH112', 'MATH113', 'MATH115', 'STAT100']
# Course: STAT110, Prereq: ['DATA100', 'STAT100', 'MATH135']
# Course: STAT400, Prereq: ['MATH131', 'MATH141']
# Course: STAT401, Prereq: ['STAT400', 'STAT410']
# Course: STAT410, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH340', 'MATH241']
# Course: STAT420, Prereq: ['SURV410', 'STAT410']
# Course: STAT426, Prereq: ['MATH241', 'MATH340', 'MATH240', 'MATH461', 'MATH341', 'STAT400', 'STAT410', 'STAT400']
# Course: STAT430, Prereq: ['STAT400', 'STAT410', 'STAT401', 'STAT420', 'STAT401', 'STAT420']
# Course: STAT440, Prereq: ['STAT401', 'STAT420']
# Course: STAT464, Prereq: []
# Course: STAT470, Prereq: ['MATH240', 'MATH461', 'MATH341', 'MATH340', 'MATH241']
# Course: STAT498A, Prereq: []
# Course: STAT601, Prereq: ['STAT600']
# Course: STAT650, Prereq: ['STAT410']
# Course: STAT689, Prereq: []
# Course: STAT701, Prereq: ['STAT700']
# Course: STAT741, Prereq: ['STAT740']
# Course: STAT799, Prereq: []
# Course: STAT808A, Prereq: []
# Course: STAT818A, Prereq: []
# Course: STAT818B, Prereq: []
# Course: STAT898, Prereq: []
# Course: STAT899, Prereq: []
# Course: INST104, Prereq: []
# Course: INST123, Prereq: []
# Course: INST126, Prereq: ['STAT100']
# Course: INST152, Prereq: []
# Course: INST154, Prereq: []
# Course: INST155, Prereq: []
# Course: INST156, Prereq: []
# Course: INST201, Prereq: []
# Course: INST204, Prereq: []
# Course: INST210, Prereq: []
# Course: INST227, Prereq: []
# Course: INST228, Prereq: []
# Course: INST309, Prereq: []
# Course: INST311, Prereq: ['PSYC100', 'SOCY105']
# Course: INST314, Prereq: ['INST126', 'GEOG276', 'STAT100', 'MATH115']
# Course: INST320, Prereq: []
# Course: INST326, Prereq: ['INST126', 'GEOG276']
# Course: INST327, Prereq: ['INST126', 'GEOG276']
# Course: INST335, Prereq: ['INST201', 'INST301', 'PSYC100']
# Course: INST341, Prereq: ['INST311']
# Course: INST346, Prereq: ['INST201', 'INST301', 'INST326', 'INST327']
# Course: INST347, Prereq: ['INST346']
# Course: INST352, Prereq: ['INST201', 'INST301', 'INST311']
# Course: INST354, Prereq: ['INST201', 'INST301', 'INST314', 'PSYC100']
# Course: INST362, Prereq: ['INST201', 'INST301', 'PSYC100', 'SOCY105', 'INST326', 'STAT100']
# Course: INST364, Prereq: ['INST201', 'INST301', 'INST327', 'STAT100', 'MATH115', 'PSYC100']
# Course: INST366, Prereq: ['INST126', 'GEOG276', 'STAT100', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'SOCY105']
# Course: INST367, Prereq: ['INST380']
# Course: INST371, Prereq: ['INST201', 'PSYC100', 'SOCY105']
# Course: INST377, Prereq: ['INST201', 'INST301', 'BSOS233', 'INST327', 'STAT100', 'MATH115']
# Course: INST380, Prereq: ['INST201', 'INST126', 'STAT100', 'PSYC100', 'SOCY105']
# Course: INST381, Prereq: ['PSYC100', 'SOCY105', 'INST126', 'INST201', 'STAT100', 'MATH115']
# Course: INST388F, Prereq: []
# Course: INST388G, Prereq: []
# Course: INST388I, Prereq: []
# Course: INST388K, Prereq: []
# Course: INST388L, Prereq: []
# Course: INST388M, Prereq: []
# Course: INST388N, Prereq: []
# Course: INST388O, Prereq: []
# Course: INST388P, Prereq: []
# Course: INST398D, Prereq: []
# Course: INST398E, Prereq: []
# Course: INST406, Prereq: ['INST380']
# Course: INST408I, Prereq: []
# Course: INST408Z, Prereq: []
# Course: INST410, Prereq: ['INST126', 'STAT100', 'PSYC100', 'SOCY105', 'INST201', 'INST301', 'MATH115']
# Course: INST414, Prereq: ['MATH115', 'STAT100', 'INST126', 'GEOG276', 'INST201', 'INST301', 'BSOS233', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'BSOS233', 'INST314']
# Course: INST443, Prereq: ['INST341', 'INST380']
# Course: INST447, Prereq: ['STAT100', 'INST327', 'INST201', 'INST301', 'BSOS233', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'BSOS233', 'INST314', 'BSOS331', 'GEOG273', 'INST326']
# Course: INST450, Prereq: ['INST327']
# Course: INST452, Prereq: ['INST126', 'GEOG276', 'PSYC100', 'BSOS233', 'STAT100', 'MATH115']
# Course: INST454, Prereq: ['INST104', 'INST126', 'INST204', 'INST380', 'INST367']
# Course: INST456, Prereq: []
# Course: INST462, Prereq: ['STAT100', 'INST201', 'INST301', 'BSOS233', 'INST126', 'GEOG276', 'AASP101', 'ANTH210', 'ANTH260', 'ECON200', 'ECON201', 'GEOG202', 'GVPT170', 'PSYC100', 'SOCY100', 'SOCY105', 'BSOS233', 'INST314']
# Course: INST463, Prereq: []
# Course: INST464, Prereq: ['INST201', 'INST126', 'MATH115', 'PSYC100', 'INST364']
# Course: INST466, Prereq: ['INST201', 'INST301', 'PSYC100', 'SOCY105']
# Course: INST467, Prereq: ['INST364']
# Course: INST470, Prereq: []
# Course: INST490, Prereq: ['INST311', 'INST314', 'INST326', 'INST327', 'INST335', 'INST346', 'INST352', 'INST362']
# Course: INST600, Prereq: []
# Course: INST604, Prereq: []
# Course: INST608B, Prereq: []
# Course: INST608S, Prereq: []
# Course: INST612, Prereq: []
# Course: INST614, Prereq: []
# Course: INST616, Prereq: []
# Course: INST622, Prereq: []
# Course: INST630, Prereq: []
# Course: INST639G, Prereq: []
# Course: INST639L, Prereq: []
# Course: INST641, Prereq: ['INST604', 'INST640']
# Course: INST646, Prereq: []
# Course: INST652, Prereq: []
# Course: INST653, Prereq: []
# Course: INST682, Prereq: []
# Course: INST702, Prereq: ['INFM605', 'INST631']
# Course: INST703, Prereq: []
# Course: INST709, Prereq: []
# Course: INST710, Prereq: []
# Course: INST711, Prereq: []
# Course: INST725, Prereq: ['INST615']
# Course: INST726, Prereq: []
# Course: INST728L, Prereq: []
# Course: INST728M, Prereq: []
# Course: INST728N, Prereq: []
# Course: INST728R, Prereq: []
# Course: INST728X, Prereq: []
# Course: INST730, Prereq: []
# Course: INST733, Prereq: ['LBSC690', 'LBSC671', 'INFM603']
# Course: INST737, Prereq: ['INST627', 'LBSC690', 'LBSC671', 'INFM603', 'JOUR652']
# Course: INST742, Prereq: ['INST604']
# Course: INST750, Prereq: ['INFM603', 'INST737']
# Course: INST762, Prereq: ['INFM603', 'INST630', 'JOUR652']
# Course: INST767, Prereq: ['INST737']
# Course: INST771, Prereq: []
# Course: INST776, Prereq: ['INST775']
# Course: INST779, Prereq: []
# Course: INST785, Prereq: ['INST604']
# Course: INST786, Prereq: ['AMST655', 'ANTH655', 'HIST610']
# Course: INST787, Prereq: ['AMST856', 'ANTH856', 'HIST810']
# Course: INST788C, Prereq: []
# Course: INST798, Prereq: []
# Course: INST799, Prereq: []
# Course: INST802, Prereq: []
# Course: INST808, Prereq: []
# Course: INST809, Prereq: []
# Course: INST818, Prereq: []
# Course: INST828, Prereq: []
# Course: INST878F, Prereq: []
# Course: INST878K, Prereq: []
# Course: INST878T, Prereq: []
# Course: INST878U, Prereq: []
# Course: INST898, Prereq: []
# Course: INST899, Prereq: []
# Course: DATA100, Prereq: ['MATH110', 'MATH112', 'MATH113', 'MATH115', 'STAT100']
# Course: DATA110, Prereq: ['DATA100', 'STAT100', 'MATH135']
# Course: DATA120, Prereq: ['STAT100', 'MATH135']
# Course: DATA200, Prereq: ['STAT100', 'MATH135']
# Course: DATA250, Prereq: ['DATA110', 'DATA120', 'MATH141']
# Course: DATA320, Prereq: ['DATA110', 'DATA120', 'DATA200', 'DATA250']
# Course: DATA350, Prereq: ['DATA100', 'STAT100', 'MATH135', 'DATA110', 'DATA120']
# Course: DATA400, Prereq: ['MATH131', 'MATH141']
# Course: DATA602, Prereq: []
# Course: DATA603, Prereq: []
# Course: DATA604, Prereq: ['DATA601', 'MSML601']
# Course: DATA605, Prereq: ['DATA602']
# Course: DATA606, Prereq: ['DATA602']
# Course: DATA641, Prereq: ['DATA603', 'MSML603']

# %%
df = pd.DataFrame(list(umd_courses.items()), columns=['Course', 'Prerequesites'])

df.to_csv("umd_course_prerequesites.csv", index=False)

df.head()
# Out:
#     Course                Prerequesites
# 0  AOSC123                           []
# 1  AOSC200  [MATH107, MATH110, MATH115]
# 2  AOSC201                           []
# 3  AOSC247                    [MATH140]
# 4  AOSC360  [MATH107, MATH113, MATH115]

# %%
expanded_data = []

for course,prereqs in umd_courses.items(): 
    for prereq in prereqs:
        expanded_data.append((course,prereq))
        
df_expanded = pd.DataFrame(expanded_data, columns=['Course', 'Prerequisite'])

df_expanded.to_csv('umd_course_prerequisites_expanded.csv', index=False)

df_expanded.head()
# Out:
#     Course Prerequisite
# 0  AOSC200      MATH107
# 1  AOSC200      MATH110
# 2  AOSC200      MATH115
# 3  AOSC247      MATH140
# 4  AOSC360      MATH107

# %%
g = nx.DiGraph()

for _, row in df_expanded.iterrows():
    course = row["Course"]
    
    prereq = row["Prerequisite"]
    
    if prereq != "None": 
        g.add_edge(prereq, course)

print(g.number_of_nodes())
print(g.number_of_edges())
# Out:
# 724
# 1454

# %%
# Centrality Measures
in_degree = nx.in_degree_centrality(g)
betweenness = nx.betweenness_centrality(g)
closeness = nx.closeness_centrality(g)

# Create DataFrame
centrality_df = pd.DataFrame({
    "Course": list(in_degree.keys()),
    "In-Degree Centrality (Importance)" : list(in_degree.values()),
    "Betweenness Centrality (Chokepoint)" : list(betweenness.values()),
    "Closeness Centrality (Efficiency)" : list(closeness.values())
})

# Sort the dataframe by chokepoint and importance Top 20
bottleneck_courses = centrality_df.sort_values(by=['Betweenness Centrality (Chokepoint)','In-Degree Centrality (Importance)'], ascending=False).head(20)

bottleneck_courses.to_csv("umd_stem_bottleneck_courses.csv", index=False)

bottleneck_courses
# Out:
#       Course  In-Degree Centrality (Importance)  \
# 4    MATH140                           0.001383
# 10   MATH141                           0.001383
# 3    MATH115                           0.004149
# 153  MATH120                           0.004149
# 20   MATH241                           0.001383
# 107  MATH246                           0.001383
# 182  CMSC216                           0.002766
# 187  CMSC351                           0.002766
# 161  CHEM241                           0.004149
# 185  CMSC330                           0.002766
# 162  CHEM242                           0.004149
# 202  MATH240                           0.002766
# 612  STAT100                           0.006916
# 106  PHYS260                           0.002766
# 122  CHEM231                           0.009682
# 181  CMSC132                           0.002766
# 183  CMSC250                           0.002766
# 82   PHYS273                           0.006916
# 18   CHEM135                           0.001383
# 124  CHEM232                           0.008299
#
#      Betweenness Centrality (Chokepoint)  Closeness Centrality (Efficiency)
# 4                               0.001411                           0.002490
# 10                              0.001324                           0.002459
# 3                               0.001137                           0.002766
# 153                             0.000302                           0.003112
# 20                              0.000293                           0.002470
# 107                             0.000292                           0.002470
# 182                             0.000280                           0.003987
# 187                             0.000272                           0.004481
# 161                             0.000270                           0.008215
# 185                             0.000256                           0.004481
# 162                             0.000243                           0.008215
# 202                             0.000234                           0.003320
# 612                             0.000227                           0.005763
# 106                             0.000220                           0.003320
# 122                             0.000212                           0.008808
# 181                             0.000181                           0.003458
# 183                             0.000181                           0.003320
# 82                              0.000161                           0.007113
# 18                              0.000159                           0.002766
# 124                             0.000142                           0.007684

# %%
from pyvis.network import Network

net = Network(notebook=True, directed=True, height='800px', width='100%', bgcolor='white', font_color='black')
net.toggle_physics(True)
for node in g.nodes:
    
    # conditions to color nodes that are in top 20 bottleneck courses
    if node in bottleneck_courses['Course'].values:
        net.add_node(node, label=node, title=f"BOTTLENECK: {node}", color = 'red', font={"size": 16})
    else:
        
        net.add_node(node, label=node, title=f"{node} (STEM Course)", color = 'blue',font={"size": 14})
        
    
for edge in g.edges:
    net.add_edge(edge[0], edge[1])
    

net.show("umd_prereq_network.html")
